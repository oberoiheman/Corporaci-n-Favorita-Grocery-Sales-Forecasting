# %% [markdown]
# ### Import

# %%
# installing scikit-optimize library for using gp minimize 
# !pip3 install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading https://files.pythonhosted.org/packages/5c/87/310b52debfbc0cb79764e5770fa3f5c18f6f0754809ea9e2fc185e1b67d3/scikit_optimize-0.7.4-py2.py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 2.3MB/s
# Collecting pyaml>=16.9
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.15.1)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.18.5)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.22.2.post1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyaml>=16.9->scikit-optimize) (3.13)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-20.4.0 scikit-optimize-0.7.4

# %%
import warnings
warnings.filterwarnings("ignore")
from skopt import gp_minimize
from skopt.space import Real, Integer
from functools import partial
from sklearn.metrics import mean_squared_error

import lightgbm as lgb
import xgboost as xgb

import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

from matplotlib import pyplot as plt
import seaborn as sns

import os

# %%
# Reference: https://www.kaggle.com/gemartin/load-data-reduce-memory-usage

def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of Dataframe is {:.3f} MB'.format(start_mem))
    
    for col in tqdm(df.columns):
        col_type = df[col].dtype
        
        if col_type != object and col_type.name != 'category' and 'datetime' not in col_type.name:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        elif 'datetime' not in col_type.name:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.3f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %% [markdown]
# ### Creating Features

# %%
# Downloading data (using wget)

file_path="favorita-grocery-sales-forecasting.zip"

if not os.path.exists(file_path):
    # !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/7391/44328/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1593984946&Signature=TZ8WhKQzNyAp%2B8IRIjBE3f9IPhSdR%2B8izTu2DDZLt1ZJS9M5q5pZsNpMGYYOCFwROdvxHPUf%2FIVoPslSOiRMcBdkBhumDs6xiOt9A5dzgUh6QqH3%2BzX%2F%2Be2FVjW2dg3a%2B%2FmqIwQLD7y%2B8gfRP82VlEMdGcxLLbRliMfy2ZK0BlMZgRZJ7%2BNmsdbm3V6Y%2Fk7YnIiDGH3bBopFwLN02mOhiqb96GC4gD813iLV5DRoSzegViOZjddjSBtKeNlFu86bo9oj2cjI%2BQrxQV%2F2I6IU1lKqXxkkdAl0oFzzfNUwlLForPg0nd8GMaYgdlM6Ga1liBl2QFahMYkwJUM6Hvv%2F6w%3D%3D&response-content-disposition=attachment%3B+filename%3Dfavorita-grocery-sales-forecasting.zip" -c -O 'favorita-grocery-sales-forecasting.zip'
else:
    print("File Already Present")
# Out:
# --2020-07-03 01:07:51--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/7391/44328/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1593984946&Signature=TZ8WhKQzNyAp%2B8IRIjBE3f9IPhSdR%2B8izTu2DDZLt1ZJS9M5q5pZsNpMGYYOCFwROdvxHPUf%2FIVoPslSOiRMcBdkBhumDs6xiOt9A5dzgUh6QqH3%2BzX%2F%2Be2FVjW2dg3a%2B%2FmqIwQLD7y%2B8gfRP82VlEMdGcxLLbRliMfy2ZK0BlMZgRZJ7%2BNmsdbm3V6Y%2Fk7YnIiDGH3bBopFwLN02mOhiqb96GC4gD813iLV5DRoSzegViOZjddjSBtKeNlFu86bo9oj2cjI%2BQrxQV%2F2I6IU1lKqXxkkdAl0oFzzfNUwlLForPg0nd8GMaYgdlM6Ga1liBl2QFahMYkwJUM6Hvv%2F6w%3D%3D&response-content-disposition=attachment%3B+filename%3Dfavorita-grocery-sales-forecasting.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.189.128, 108.177.125.128, 74.125.203.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.189.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 480014675 (458M) [application/zip]
# Saving to: ‘favorita-grocery-sales-forecasting.zip’
#
# favorita-grocery-sa 100%[===================>] 457.78M  25.3MB/s    in 18s
#
# 2020-07-03 01:08:11 (25.1 MB/s) - ‘favorita-grocery-sales-forecasting.zip’ saved [480014675/480014675]

# %%
# unzipping favorita-grocery-sales-forecasting.zip

if os.path.exists('favorita-grocery-sales-forecasting.zip'):
    # !unzip 'favorita-grocery-sales-forecasting.zip'
    print("File unzipped Successfully")
else:
    print("File Not Present to unzip")
# Out:
# Archive:  favorita-grocery-sales-forecasting.zip
#   inflating: holidays_events.csv.7z
#   inflating: items.csv.7z
#   inflating: oil.csv.7z
#   inflating: sample_submission.csv.7z
#   inflating: stores.csv.7z
#   inflating: test.csv.7z
#   inflating: train.csv.7z
#   inflating: transactions.csv.7z
# File unzipped Successfully

# %%
#installing 7zip for extracting .7z files
# !apt-get install p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.

# %%
#Extracting .7z files if they are not already extracted.

for file in os.listdir():
    if file[-3:]=='.7z':
        if os.path.exists(file[:-3]):
            print("="*50)
            print("'{}'Extracted File is Already Present".format(file[:-3]))
        elif file=='oil.csv.7z':
            # !p7zip -d 'oil.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='train.csv.7z':
            # !p7zip -d 'train.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='stores.csv.7z':
            # !p7zip -d 'stores.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='transactions.csv.7z':
            # !p7zip -d 'transactions.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='items.csv.7z':
            # !p7zip -d 'items.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='holidays_events.csv.7z':
            # !p7zip -d 'holidays_events.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='test.csv.7z':
            # !p7zip -d 'test.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='sample_submission.csv.7z':
            # !p7zip -d 'sample_submission.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        print("="*50)
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 666528 bytes (651 KiB)
#
# Extracting archive: sample_submission.csv.7z
# --
# Path = sample_submission.csv.7z
# Type = 7z
# Physical Size = 666528
# Headers Size = 146
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       40445582
# Compressed: 666528
# ==================================================
# 'sample_submission.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 474092593 bytes (453 MiB)
#
# Extracting archive: train.csv.7z
# --
# Path = train.csv.7z
# Type = 7z
# Physical Size = 474092593
# Headers Size = 122
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       4997452288
# Compressed: 474092593
# ==================================================
# 'train.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 3762 bytes (4 KiB)
#
# Extracting archive: oil.csv.7z
# --
# Path = oil.csv.7z
# Type = 7z
# Physical Size = 3762
# Headers Size = 122
# Method = LZMA2:24k
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       20580
# Compressed: 3762
# ==================================================
# 'oil.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 648 bytes (1 KiB)
#
# Extracting archive: stores.csv.7z
# --
# Path = stores.csv.7z
# Type = 7z
# Physical Size = 648
# Headers Size = 130
# Method = LZMA2:12
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       1387
# Compressed: 648
# ==================================================
# 'stores.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 14315 bytes (14 KiB)
#
# Extracting archive: items.csv.7z
# --
# Path = items.csv.7z
# Type = 7z
# Physical Size = 14315
# Headers Size = 122
# Method = LZMA2:17
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       101841
# Compressed: 14315
# ==================================================
# 'items.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1898 bytes (2 KiB)
#
# Extracting archive: holidays_events.csv.7z
# --
# Path = holidays_events.csv.7z
# Type = 7z
# Physical Size = 1898
# Headers Size = 146
# Method = LZMA2:24k
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       22309
# Compressed: 1898
# ==================================================
# 'holidays_events.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 219499 bytes (215 KiB)
#
# Extracting archive: transactions.csv.7z
# --
# Path = transactions.csv.7z
# Type = 7z
# Physical Size = 219499
# Headers Size = 138
# Method = LZMA2:1536k
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       1552637
# Compressed: 219499
# ==================================================
# 'transactions.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 4885065 bytes (4771 KiB)
#
# Extracting archive: test.csv.7z
# --
# Path = test.csv.7z
# Type = 7z
# Physical Size = 4885065
# Headers Size = 122
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       126163026
# Compressed: 4885065
# ==================================================
# 'test.csv.7z' File Extracted Successfully
# ==================================================

# %%
#Creating features by excecuting Pre_Processing Feature_engineering.py

exec(open('Pre_Processing Feature_engineering.py').read())

# Train Dataset Initial Date 28/6/2017
# 2 weeks

# Validation Dataset Initial Date 26/7/2017
# 1 week

# Test Dataset Initial Date 16/8/2017
# 1 week
# Out:
# Data Pre-Processing ...
# HBox(children=(FloatProgress(value=0.0, max=23808261.0), HTML(value='')))
# Enter the following for Train Data :
#
# Starting Date (Day/Month/Year) --> 28/6/2017
# No. of weeks --> 2
#
# Creating Features for data between Dates --> 2017-06-28 - 2017-07-12 (i.e. 2 weeks)
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# Saving 'X_train.csv' File ...
# Saving 'y_train.csv' File ...
#
# Enter the following for Validation Data :
#
# Starting Date (Day/Month/Year) --> 26/7/2017
# No. of weeks --> 1
#
# Creating Features for data between Dates --> 2017-07-26 - 2017-08-02 (i.e. 1 weeks)
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Saving 'X_val.csv' File ...
# Saving 'y_val.csv' File ...
#
# Enter the following for Test Data :
#
# Starting Date (Day/Month/Year) --> 16/8/2017
# No. of weeks --> 1
#
# Creating Features for data between Dates --> 2017-08-16 - 2017-08-23 (i.e. 1 weeks)
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Saving 'X_test.csv' File ...
#
# Saving 'sales_2017.csv' File ...
# Saving 'stores_items.csv' File ...

# %%
# Reducing memory usages of dataframes

X_train=reduce_mem_usage(X_train)
X_val=reduce_mem_usage(X_val)
X_test=reduce_mem_usage(X_test)
# Out:
# Memory usage of Dataframe is 1405.842 MB
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# Memory usage after optimization is: 384.689 MB
# Decreased by 72.6%
# Memory usage of Dataframe is 701.643 MB
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# Memory usage after optimization is: 190.428 MB
# Decreased by 72.9%
# Memory usage of Dataframe is 701.643 MB
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# Memory usage after optimization is: 191.067 MB
# Decreased by 72.8%

# %% [markdown]
# ### Reading Data

# %%
# Reading X_train.csv and reducing memory usage
X_train=pd.read_csv("X_train.csv")
X_train=reduce_mem_usage(X_train)

# Reading y_train.csv and converting into numpy array
y_train = np.array(pd.read_csv( 'y_train.csv'))
# Out:
# Memory usage of Dataframe is 1617.996 MB
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# Memory usage after optimization is: 351.461 MB
# Decreased by 78.3%

# %%
# Reading X_val.csv and reducing memory usage
X_val=pd.read_csv("X_val.csv")
X_val=reduce_mem_usage(X_val)

# Reading y_val.csv and converting into numpy array
y_val = np.array(pd.read_csv( 'y_val.csv'))
# Out:
# Memory usage of Dataframe is 808.998 MB
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# Memory usage after optimization is: 175.091 MB
# Decreased by 78.4%

# %%
# Reading X_test.csv and reducing memory usage
X_test=pd.read_csv("X_test.csv")
X_test=reduce_mem_usage(X_test)
# Out:
# Memory usage of Dataframe is 808.998 MB
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# Memory usage after optimization is: 175.730 MB
# Decreased by 78.3%

# %%
# Reading stores_items.csv
stores_items = pd.read_csv('stores_items.csv', index_col=['store_nbr','item_nbr'])

# Reading items.csv and setting index as item_nbr
items = pd.read_csv( 'items.csv' ).set_index("item_nbr")

items = items.reindex( stores_items.index.get_level_values(1) )
items=reduce_mem_usage(items)
# Out:
# Memory usage of Dataframe is 5.112 MB
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Memory usage after optimization is: 1.919 MB
# Decreased by 62.5%

# %% [markdown]
# ### Feature Selection

# %%
# Loading Top 300 Feature Names (got by training random forest)
import pickle
with open('300_filtered_features.pkl','rb') as file:
    filtered_features = pickle.load( file)

# %% [markdown]
# ### Defining Rf model

# %%
def train_rf_model(X_train,y_train,X_val,y_val,params,n_days,items,features,X_test=None):
    '''
    Filter features from the Dataset and then
    Trains 16 different Random forest models for predicting next 16 days sales . 

    Returns --> * val_pred i.e.predicted values of validation data
                * test_pred i.e.predicted values of test data if present
    '''

    #Standalone Random Forest With XGBoost API

    params['objective'] = 'reg:squarederror'
    params['eval_metric'] = 'rmse'
    params['tree_method'] = 'gpu_hist'

    #num_boost_round should be set to 1 to prevent XGBoost from boosting multiple random forests. 
    num_boost_rounds=1
    #eta (alias: learning_rate) must be set to 1 when training random forest regression
    params ['eta']= 1

    val_pred = []
    test_pred = []

    #Training 16 different models for predicting next 16 days sales.
    for i in range(16):
        print("=" * 50)
        print("Step %d" % (i+1))

        # Filtering features
        x_train = X_train[features[i]]
        x_val = X_val[features[i]]

        #Filtering Features from test dataset if it exists.
        try:
            x_test = X_test[features[i]]
        except:
            pass

        #Creating Train Dmatrix (DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed.)
        dtrain = xgb.DMatrix( x_train, label=y_train[:, i],
                              weight=pd.concat([items["perishable"]] * n_days) * 0.25 + 1)
        
        #Creating Validation Dmatrix
        dval = xgb.DMatrix( x_val, label=y_val[:, i],
                            weight=items["perishable"] * 0.25 + 1)
        
        # watchist is used to see the evaluation metrics of the datasets given while training
        watchlist = [ (dtrain,'train'), (dval,'val') ]

        #Training Random Forest using Xgboost
        model = xgb.train(params, dtrain, 1, watchlist, verbose_eval=50)


        val_pred.append(model.predict(xgb.DMatrix(x_val)))

        # appending results of prediction on test set if it exists
        try:
            test_pred.append(model.predict(xgb.DMatrix(x_test)))
        except:
            pass

        # Deleting unneccessary variables
        del model,dtrain,dval,x_train,x_val

    if type(X_test) != type(None):
        return val_pred,test_pred
    else:
        return val_pred

# %% [markdown]
# ### Performance Metric

# %% [markdown]
# **NWRMSLE** (Normalized Weighted Root Mean Squared Logarithmic Error)

# %%
def calculate_nwrmsle(true,pred,weight):
    ''' 
    Calculates Normalized Weighted Root Mean Squared Logarithmic Error (nwrmsle)

    true = true labels
    pred =  predicted labels
    weight = weights of datapoints

    returns nwrmsle '''

    temp = (true - np.array(pred).transpose())**2
    temp = temp.sum(axis=1) * weight
    nwrmsle = np.sqrt(temp.sum() / weight.sum() / 16)
    return nwrmsle

# %% [markdown]
# ### HyperParameter Tuning (Using gp minimize)

# %%
# function to fit the model and return the performance of the model
def return_model_assessment(args, X_train, y_train, X_val, y_val, model, n_days ,items , features ,num_boost_rounds =None):
    global model_hyper_params,count
    count+=1
    print('='*50)
    print("\nTraining Model No. {} ...".format(count))
    params = {model_hyper_params[i]: args[i] for i, j in enumerate(model_hyper_params)}
    print("Parameters --> ",params)


    if model=='xgb':
        val_pred = train_xgb_model(X_train,y_train,X_val,y_val,params,num_boost_rounds,n_days,items,features)

    elif model=='lgb':
        val_pred = train_lgb_model(X_train,y_train,X_val,y_val,params,num_boost_rounds,n_days,items,features)

    elif model== 'rf' :
        val_pred = train_rf_model(X_train,y_train,X_val,y_val,params,n_days,items,features)

    #calculating nwrmsle
    weight = items["perishable"] * 0.25 + 1
    nwrmsle = calculate_nwrmsle(y_val, y_pred, weight)

    return nwrmsle      #returning nwrmsle because we want to minimize it.

# %%
# %%time



space = [    
    Integer(5, 20, name="max_depth"),
    Integer(10, 1000, name="num_parallel_tree"),
    Real(0.1, 0.9, name="subsample"),            #subsample must be set to a value less than 1 to enable random selection of training cases (rows).
    Real(0.1, 0.9, name="colsample_bynode"),     #colsample_bynode would be set to a value less than 1 to randomly sample columns at each tree split.
    ]

count=0
model_hyper_params = ['max_depth', 'num_parallel_tree', 'subsample', 'colsample_bynode']

# Objective function which will return nwrmsle .
objective_function = partial(return_model_assessment,
                             X_train=X_train, y_train=y_train, X_val = X_val,y_val= y_val ,
                             model='rf', n_days=2, items=items , 
                             features= filtered_features)
# running the algorithm
n_calls = 10 # number of times you want to train your model
results = gp_minimize(objective_function, space, base_estimator=None, n_calls=n_calls, n_random_starts=n_calls-1, random_state=42)
# Out:
# ==================================================
#
# Training Model No. 1 ...
# Parameters -->  {'max_depth': 17, 'num_parallel_tree': 192, 'subsample': 0.7237528002182156, 'colsample_bynode': 0.5774801263571897}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.463539	val-rmse:0.541145
# ==================================================
# Step 2
#
# [0]	train-rmse:0.480869	val-rmse:0.571181
# ==================================================
# Step 3
#
# [0]	train-rmse:0.47349	val-rmse:0.586381
# ==================================================
# Step 4
#
# [0]	train-rmse:0.489386	val-rmse:0.598407
# ==================================================
# Step 5
#
# [0]	train-rmse:0.491184	val-rmse:0.603215
# ==================================================
# Step 6
#
# [0]	train-rmse:0.504993	val-rmse:0.603774
# ==================================================
# Step 7
#
# [0]	train-rmse:0.496033	val-rmse:0.650859
# ==================================================
# Step 8
#
# [0]	train-rmse:0.480461	val-rmse:0.621561
# ==================================================
# Step 9
#
# [0]	train-rmse:0.491559	val-rmse:0.616881
# ==================================================
# Step 10
#
# [0]	train-rmse:0.485035	val-rmse:0.609646
# ==================================================
# Step 11
#
# [0]	train-rmse:0.507533	val-rmse:0.614836
# ==================================================
# Step 12
#
# [0]	train-rmse:0.505083	val-rmse:0.623614
# ==================================================
# Step 13
#
# [0]	train-rmse:0.510536	val-rmse:0.617206
# ==================================================
# Step 14
#
# [0]	train-rmse:0.499748	val-rmse:0.605247
# ==================================================
# Step 15
#
# [0]	train-rmse:0.485737	val-rmse:0.592154
# ==================================================
# Step 16
#
# [0]	train-rmse:0.493382	val-rmse:0.613584
# ==================================================
#
# Training Model No. 2 ...
# Parameters -->  {'max_depth': 12, 'num_parallel_tree': 109, 'subsample': 0.4673991135726938, 'colsample_bynode': 0.36696688891121754}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.522504	val-rmse:0.542962
# ==================================================
# Step 2
#
# [0]	train-rmse:0.538951	val-rmse:0.571883
# ==================================================
# Step 3
#
# [0]	train-rmse:0.535754	val-rmse:0.585747
# ==================================================
# Step 4
#
# [0]	train-rmse:0.557878	val-rmse:0.599873
# ==================================================
# Step 5
#
# [0]	train-rmse:0.565759	val-rmse:0.604632
# ==================================================
# Step 6
#
# [0]	train-rmse:0.567558	val-rmse:0.603021
# ==================================================
# Step 7
#
# [0]	train-rmse:0.559906	val-rmse:0.646479
# ==================================================
# Step 8
#
# [0]	train-rmse:0.543375	val-rmse:0.618414
# ==================================================
# Step 9
#
# [0]	train-rmse:0.555576	val-rmse:0.613952
# ==================================================
# Step 10
#
# [0]	train-rmse:0.553112	val-rmse:0.607452
# ==================================================
# Step 11
#
# [0]	train-rmse:0.569621	val-rmse:0.614564
# ==================================================
# Step 12
#
# [0]	train-rmse:0.576869	val-rmse:0.623748
# ==================================================
# Step 13
#
# [0]	train-rmse:0.57083	val-rmse:0.615663
# ==================================================
# Step 14
#
# [0]	train-rmse:0.561313	val-rmse:0.603632
# ==================================================
# Step 15
#
# [0]	train-rmse:0.551395	val-rmse:0.591337
# ==================================================
# Step 16
#
# [0]	train-rmse:0.562179	val-rmse:0.612397
# ==================================================
#
# Training Model No. 3 ...
# Parameters -->  {'max_depth': 7, 'num_parallel_tree': 654, 'subsample': 0.14512926322168024, 'colsample_bynode': 0.6775990178134599}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.553453	val-rmse:0.553138
# ==================================================
# Step 2
#
# [0]	train-rmse:0.567201	val-rmse:0.579795
# ==================================================
# Step 3
#
# [0]	train-rmse:0.570214	val-rmse:0.594154
# ==================================================
# Step 4
#
# [0]	train-rmse:0.595754	val-rmse:0.609312
# ==================================================
# Step 5
#
# [0]	train-rmse:0.60741	val-rmse:0.616546
# ==================================================
# Step 6
#
# [0]	train-rmse:0.602651	val-rmse:0.609527
# ==================================================
# Step 7
#
# [0]	train-rmse:0.595923	val-rmse:0.648004
# ==================================================
# Step 8
#
# [0]	train-rmse:0.580591	val-rmse:0.62355
# ==================================================
# Step 9
#
# [0]	train-rmse:0.589486	val-rmse:0.616742
# ==================================================
# Step 10
#
# [0]	train-rmse:0.59306	val-rmse:0.614047
# ==================================================
# Step 11
#
# [0]	train-rmse:0.608089	val-rmse:0.620301
# ==================================================
# Step 12
#
# [0]	train-rmse:0.621571	val-rmse:0.632938
# ==================================================
# Step 13
#
# [0]	train-rmse:0.608323	val-rmse:0.620263
# ==================================================
# Step 14
#
# [0]	train-rmse:0.598243	val-rmse:0.608223
# ==================================================
# Step 15
#
# [0]	train-rmse:0.590306	val-rmse:0.598817
# ==================================================
# Step 16
#
# [0]	train-rmse:0.598654	val-rmse:0.616522
# ==================================================
#
# Training Model No. 4 ...
# Parameters -->  {'max_depth': 19, 'num_parallel_tree': 11, 'subsample': 0.8937692474329743, 'colsample_bynode': 0.5939852077021733}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.426194	val-rmse:0.548576
# ==================================================
# Step 2
#
# [0]	train-rmse:0.442555	val-rmse:0.579269
# ==================================================
# Step 3
#
# [0]	train-rmse:0.435933	val-rmse:0.594364
# ==================================================
# Step 4
#
# [0]	train-rmse:0.449835	val-rmse:0.608329
# ==================================================
# Step 5
#
# [0]	train-rmse:0.448232	val-rmse:0.612875
# ==================================================
# Step 6
#
# [0]	train-rmse:0.465087	val-rmse:0.612456
# ==================================================
# Step 7
#
# [0]	train-rmse:0.457124	val-rmse:0.6604
# ==================================================
# Step 8
#
# [0]	train-rmse:0.444701	val-rmse:0.632044
# ==================================================
# Step 9
#
# [0]	train-rmse:0.45365	val-rmse:0.623928
# ==================================================
# Step 10
#
# [0]	train-rmse:0.444465	val-rmse:0.619754
# ==================================================
# Step 11
#
# [0]	train-rmse:0.471244	val-rmse:0.6244
# ==================================================
# Step 12
#
# [0]	train-rmse:0.46616	val-rmse:0.633389
# ==================================================
# Step 13
#
# [0]	train-rmse:0.478023	val-rmse:0.625191
# ==================================================
# Step 14
#
# [0]	train-rmse:0.462554	val-rmse:0.614028
# ==================================================
# Step 15
#
# [0]	train-rmse:0.448334	val-rmse:0.601205
# ==================================================
# Step 16
#
# [0]	train-rmse:0.453275	val-rmse:0.622238
# ==================================================
#
# Training Model No. 5 ...
# Parameters -->  {'max_depth': 14, 'num_parallel_tree': 17, 'subsample': 0.11844994003313261, 'colsample_bynode': 0.5198197282067114}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.536402	val-rmse:0.549773
# ==================================================
# Step 2
#
# [0]	train-rmse:0.55192	val-rmse:0.579323
# ==================================================
# Step 3
#
# [0]	train-rmse:0.551758	val-rmse:0.594385
# ==================================================
# Step 4
#
# [0]	train-rmse:0.575804	val-rmse:0.609541
# ==================================================
# Step 5
#
# [0]	train-rmse:0.584657	val-rmse:0.614698
# ==================================================
# Step 6
#
# [0]	train-rmse:0.583907	val-rmse:0.612702
# ==================================================
# Step 7
#
# [0]	train-rmse:0.577446	val-rmse:0.655917
# ==================================================
# Step 8
#
# [0]	train-rmse:0.560701	val-rmse:0.629358
# ==================================================
# Step 9
#
# [0]	train-rmse:0.571409	val-rmse:0.622422
# ==================================================
# Step 10
#
# [0]	train-rmse:0.57011	val-rmse:0.616575
# ==================================================
# Step 11
#
# [0]	train-rmse:0.588515	val-rmse:0.621865
# ==================================================
# Step 12
#
# [0]	train-rmse:0.596349	val-rmse:0.631464
# ==================================================
# Step 13
#
# [0]	train-rmse:0.588392	val-rmse:0.623435
# ==================================================
# Step 14
#
# [0]	train-rmse:0.578432	val-rmse:0.611276
# ==================================================
# Step 15
#
# [0]	train-rmse:0.567991	val-rmse:0.599027
# ==================================================
# Step 16
#
# [0]	train-rmse:0.578957	val-rmse:0.620161
# ==================================================
#
# Training Model No. 6 ...
# Parameters -->  {'max_depth': 11, 'num_parallel_tree': 56, 'subsample': 0.8790044150731675, 'colsample_bynode': 0.28621707234424343}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.524456	val-rmse:0.543484
# ==================================================
# Step 2
#
# [0]	train-rmse:0.540514	val-rmse:0.571541
# ==================================================
# Step 3
#
# [0]	train-rmse:0.538107	val-rmse:0.585867
# ==================================================
# Step 4
#
# [0]	train-rmse:0.559803	val-rmse:0.59945
# ==================================================
# Step 5
#
# [0]	train-rmse:0.567656	val-rmse:0.604257
# ==================================================
# Step 6
#
# [0]	train-rmse:0.569271	val-rmse:0.602193
# ==================================================
# Step 7
#
# [0]	train-rmse:0.561589	val-rmse:0.645262
# ==================================================
# Step 8
#
# [0]	train-rmse:0.54546	val-rmse:0.617195
# ==================================================
# Step 9
#
# [0]	train-rmse:0.557779	val-rmse:0.613314
# ==================================================
# Step 10
#
# [0]	train-rmse:0.556452	val-rmse:0.607335
# ==================================================
# Step 11
#
# [0]	train-rmse:0.57175	val-rmse:0.614626
# ==================================================
# Step 12
#
# [0]	train-rmse:0.578784	val-rmse:0.623734
# ==================================================
# Step 13
#
# [0]	train-rmse:0.573152	val-rmse:0.615678
# ==================================================
# Step 14
#
# [0]	train-rmse:0.562379	val-rmse:0.602676
# ==================================================
# Step 15
#
# [0]	train-rmse:0.554167	val-rmse:0.590877
# ==================================================
# Step 16
#
# [0]	train-rmse:0.564935	val-rmse:0.612057
# ==================================================
#
# Training Model No. 7 ...
# Parameters -->  {'max_depth': 6, 'num_parallel_tree': 622, 'subsample': 0.40596959301373026, 'colsample_bynode': 0.8865847086454307}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.558819	val-rmse:0.558156
# ==================================================
# Step 2
#
# [0]	train-rmse:0.572612	val-rmse:0.583915
# ==================================================
# Step 3
#
# [0]	train-rmse:0.577713	val-rmse:0.600451
# ==================================================
# Step 4
#
# [0]	train-rmse:0.603317	val-rmse:0.613639
# ==================================================
# Step 5
#
# [0]	train-rmse:0.615819	val-rmse:0.622212
# ==================================================
# Step 6
#
# [0]	train-rmse:0.608627	val-rmse:0.612481
# ==================================================
# Step 7
#
# [0]	train-rmse:0.603056	val-rmse:0.651079
# ==================================================
# Step 8
#
# [0]	train-rmse:0.588386	val-rmse:0.627641
# ==================================================
# Step 9
#
# [0]	train-rmse:0.59551	val-rmse:0.620894
# ==================================================
# Step 10
#
# [0]	train-rmse:0.601015	val-rmse:0.618981
# ==================================================
# Step 11
#
# [0]	train-rmse:0.615998	val-rmse:0.625013
# ==================================================
# Step 12
#
# [0]	train-rmse:0.632554	val-rmse:0.63998
# ==================================================
# Step 13
#
# [0]	train-rmse:0.616176	val-rmse:0.625273
# ==================================================
# Step 14
#
# [0]	train-rmse:0.605247	val-rmse:0.612643
# ==================================================
# Step 15
#
# [0]	train-rmse:0.598771	val-rmse:0.604104
# ==================================================
# Step 16
#
# [0]	train-rmse:0.605222	val-rmse:0.620382
# ==================================================
#
# Training Model No. 8 ...
# Parameters -->  {'max_depth': 12, 'num_parallel_tree': 861, 'subsample': 0.6442460308702238, 'colsample_bynode': 0.4603994015756345}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.517884	val-rmse:0.541928
# ==================================================
# Step 2
#
# [0]	train-rmse:0.53493	val-rmse:0.571284
# ==================================================
# Step 3
#
# [0]	train-rmse:0.531242	val-rmse:0.585382
# ==================================================
# Step 4
#
# [0]	train-rmse:0.552893	val-rmse:0.598718
# ==================================================
# Step 5
#
# [0]	train-rmse:0.56046	val-rmse:0.603634
# ==================================================
# Step 6
#
# [0]	train-rmse:0.563762	val-rmse:0.602052
# ==================================================
# Step 7
#
# [0]	train-rmse:0.55559	val-rmse:0.646634
# ==================================================
# Step 8
#
# [0]	train-rmse:0.53898	val-rmse:0.617628
# ==================================================
# Step 9
#
# [0]	train-rmse:0.55134	val-rmse:0.613575
# ==================================================
# Step 10
#
# [0]	train-rmse:0.548786	val-rmse:0.607132
# ==================================================
# Step 11
#
# [0]	train-rmse:0.564906	val-rmse:0.613783
# ==================================================
# Step 12
#
# [0]	train-rmse:0.57128	val-rmse:0.623088
# ==================================================
# Step 13
#
# [0]	train-rmse:0.566683	val-rmse:0.61537
# ==================================================
# Step 14
#
# [0]	train-rmse:0.556602	val-rmse:0.603188
# ==================================================
# Step 15
#
# [0]	train-rmse:0.546701	val-rmse:0.591007
# ==================================================
# Step 16
#
# [0]	train-rmse:0.557706	val-rmse:0.611993
# ==================================================
#
# Training Model No. 9 ...
# Parameters -->  {'max_depth': 5, 'num_parallel_tree': 943, 'subsample': 0.5506305742764316, 'colsample_bynode': 0.408333202031933}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.571192	val-rmse:0.568475
# ==================================================
# Step 2
#
# [0]	train-rmse:0.580915	val-rmse:0.59072
# ==================================================
# Step 3
#
# [0]	train-rmse:0.589845	val-rmse:0.608859
# ==================================================
# Step 4
#
# [0]	train-rmse:0.610933	val-rmse:0.621078
# ==================================================
# Step 5
#
# [0]	train-rmse:0.624631	val-rmse:0.62954
# ==================================================
# Step 6
#
# [0]	train-rmse:0.61803	val-rmse:0.619543
# ==================================================
# Step 7
#
# [0]	train-rmse:0.613475	val-rmse:0.65571
# ==================================================
# Step 8
#
# [0]	train-rmse:0.599094	val-rmse:0.634728
# ==================================================
# Step 9
#
# [0]	train-rmse:0.605339	val-rmse:0.625687
# ==================================================
# Step 10
#
# [0]	train-rmse:0.611624	val-rmse:0.625609
# ==================================================
# Step 11
#
# [0]	train-rmse:0.62642	val-rmse:0.631728
# ==================================================
# Step 12
#
# [0]	train-rmse:0.641568	val-rmse:0.646139
# ==================================================
# Step 13
#
# [0]	train-rmse:0.62645	val-rmse:0.631981
# ==================================================
# Step 14
#
# [0]	train-rmse:0.614062	val-rmse:0.617608
# ==================================================
# Step 15
#
# [0]	train-rmse:0.608002	val-rmse:0.608802
# ==================================================
# Step 16
#
# [0]	train-rmse:0.612125	val-rmse:0.624128
# ==================================================
#
# Training Model No. 10 ...
# Parameters -->  {'max_depth': 18, 'num_parallel_tree': 1000, 'subsample': 0.9, 'colsample_bynode': 0.1}
# ==================================================
# Step 1
#
# [0]	train-rmse:0.433606	val-rmse:0.545345
# ==================================================
# Step 2
#
# [0]	train-rmse:0.451609	val-rmse:0.571401
# ==================================================
# Step 3
#
# [0]	train-rmse:0.443905	val-rmse:0.586679
# ==================================================
# Step 4
#
# [0]	train-rmse:0.456539	val-rmse:0.600051
# ==================================================
# Step 5
#
# [0]	train-rmse:0.452996	val-rmse:0.603113
# ==================================================
# Step 6
#
# [0]	train-rmse:0.466993	val-rmse:0.605854
# ==================================================
# Step 7
#
# [0]	train-rmse:0.455609	val-rmse:0.650868
# ==================================================
# Step 8
#
# [0]	train-rmse:0.446707	val-rmse:0.623773
# ==================================================
# Step 9
#
# [0]	train-rmse:0.456113	val-rmse:0.617469
# ==================================================
# Step 10
#
# [0]	train-rmse:0.452363	val-rmse:0.61145
# ==================================================
# Step 11
#
# [0]	train-rmse:0.472736	val-rmse:0.616916
# ==================================================
# Step 12
#
# [0]	train-rmse:0.465968	val-rmse:0.624726
# ==================================================
# Step 13
#
# [0]	train-rmse:0.47201	val-rmse:0.617072
# ==================================================
# Step 14
#
# [0]	train-rmse:0.462567	val-rmse:0.605609
# ==================================================
# Step 15
#
# [0]	train-rmse:0.455004	val-rmse:0.592696
# ==================================================
# Step 16
#
# [0]	train-rmse:0.461429	val-rmse:0.613808

# %%
print("""Best parameters:
- max_depth = %d
- num_parallel_tree = %d
- subsample = %.6f
- colsample_bynode = %.6f """ % (results.x[0], results.x[1],
                            results.x[2], results.x[3]))
# Out:
# Best parameters:
# - max_depth = 18
# - num_parallel_tree = 1000
# - subsample = 0.900000
# - colsample_bynode = 0.100000

# %%
"Best score = %.6f" % results.fun
# Out:
# 'Best score = 0.605871'

# %% [markdown]
# ### Observations :

# %% [markdown]
# * Model --> **Random Forest**
# * Best Parameters :
#     * *max_depth* = **18**
#     * *num_parallel_tree* = **1000**
#     * *subsample* = **0.9**
#     * *colsample_bynode* = **0.1**
#
# * Best Score (NWRMSLE) = **0.6058**

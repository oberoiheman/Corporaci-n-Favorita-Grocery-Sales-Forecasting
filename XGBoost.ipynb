# %% [markdown]
# ### Import

# %%
# installing scikit-optimize library for using gp minimize 
# !pip3 install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading https://files.pythonhosted.org/packages/5c/87/310b52debfbc0cb79764e5770fa3f5c18f6f0754809ea9e2fc185e1b67d3/scikit_optimize-0.7.4-py2.py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 2.8MB/s
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.18.5)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize) (0.15.1)
# Collecting pyaml>=16.9
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyaml>=16.9->scikit-optimize) (3.13)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-20.4.0 scikit-optimize-0.7.4

# %%
import warnings
warnings.filterwarnings("ignore")
from skopt import gp_minimize
from skopt.space import Real, Integer
from functools import partial
from sklearn.metrics import mean_squared_error

import lightgbm as lgb
import xgboost as xgb

import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

from matplotlib import pyplot as plt
import seaborn as sns

import os

# %%
# Reference: https://www.kaggle.com/gemartin/load-data-reduce-memory-usage

def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of Dataframe is {:.3f} MB'.format(start_mem))
    
    for col in tqdm(df.columns):
        col_type = df[col].dtype
        
        if col_type != object and col_type.name != 'category' and 'datetime' not in col_type.name:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        elif 'datetime' not in col_type.name:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.3f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %% [markdown]
# ### Creating Features

# %%
# Downloading data (using wget)

file_path="favorita-grocery-sales-forecasting.zip"

if not os.path.exists(file_path):
    # !wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/7391/44328/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1593984946&Signature=TZ8WhKQzNyAp%2B8IRIjBE3f9IPhSdR%2B8izTu2DDZLt1ZJS9M5q5pZsNpMGYYOCFwROdvxHPUf%2FIVoPslSOiRMcBdkBhumDs6xiOt9A5dzgUh6QqH3%2BzX%2F%2Be2FVjW2dg3a%2B%2FmqIwQLD7y%2B8gfRP82VlEMdGcxLLbRliMfy2ZK0BlMZgRZJ7%2BNmsdbm3V6Y%2Fk7YnIiDGH3bBopFwLN02mOhiqb96GC4gD813iLV5DRoSzegViOZjddjSBtKeNlFu86bo9oj2cjI%2BQrxQV%2F2I6IU1lKqXxkkdAl0oFzzfNUwlLForPg0nd8GMaYgdlM6Ga1liBl2QFahMYkwJUM6Hvv%2F6w%3D%3D&response-content-disposition=attachment%3B+filename%3Dfavorita-grocery-sales-forecasting.zip" -c -O 'favorita-grocery-sales-forecasting.zip'
else:
    print("File Already Present")
# Out:
# --2020-07-03 19:45:21--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/7391/44328/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1593984946&Signature=TZ8WhKQzNyAp%2B8IRIjBE3f9IPhSdR%2B8izTu2DDZLt1ZJS9M5q5pZsNpMGYYOCFwROdvxHPUf%2FIVoPslSOiRMcBdkBhumDs6xiOt9A5dzgUh6QqH3%2BzX%2F%2Be2FVjW2dg3a%2B%2FmqIwQLD7y%2B8gfRP82VlEMdGcxLLbRliMfy2ZK0BlMZgRZJ7%2BNmsdbm3V6Y%2Fk7YnIiDGH3bBopFwLN02mOhiqb96GC4gD813iLV5DRoSzegViOZjddjSBtKeNlFu86bo9oj2cjI%2BQrxQV%2F2I6IU1lKqXxkkdAl0oFzzfNUwlLForPg0nd8GMaYgdlM6Ga1liBl2QFahMYkwJUM6Hvv%2F6w%3D%3D&response-content-disposition=attachment%3B+filename%3Dfavorita-grocery-sales-forecasting.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.197.128, 74.125.142.128, 74.125.195.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.197.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 480014675 (458M) [application/zip]
# Saving to: ‘favorita-grocery-sales-forecasting.zip’
#
# favorita-grocery-sa 100%[===================>] 457.78M  76.5MB/s    in 6.2s
#
# 2020-07-03 19:45:27 (74.0 MB/s) - ‘favorita-grocery-sales-forecasting.zip’ saved [480014675/480014675]

# %%
# unzipping favorita-grocery-sales-forecasting.zip

if os.path.exists('favorita-grocery-sales-forecasting.zip'):
    # !unzip 'favorita-grocery-sales-forecasting.zip'
    print("File unzipped Successfully")
else:
    print("File Not Present to unzip")
# Out:
# Archive:  favorita-grocery-sales-forecasting.zip
#   inflating: holidays_events.csv.7z
#   inflating: items.csv.7z
#   inflating: oil.csv.7z
#   inflating: sample_submission.csv.7z
#   inflating: stores.csv.7z
#   inflating: test.csv.7z
#   inflating: train.csv.7z
#   inflating: transactions.csv.7z
# File unzipped Successfully

# %%
#installing 7zip for extracting .7z files
# !apt-get install p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.

# %%
#Extracting .7z files if they are not already extracted.

for file in os.listdir():
    if file[-3:]=='.7z':
        if os.path.exists(file[:-3]):
            print("="*50)
            print("'{}'Extracted File is Already Present".format(file[:-3]))
        elif file=='oil.csv.7z':
            # !p7zip -d 'oil.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='train.csv.7z':
            # !p7zip -d 'train.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='stores.csv.7z':
            # !p7zip -d 'stores.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='transactions.csv.7z':
            # !p7zip -d 'transactions.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='items.csv.7z':
            # !p7zip -d 'items.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='holidays_events.csv.7z':
            # !p7zip -d 'holidays_events.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='test.csv.7z':
            # !p7zip -d 'test.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        elif file=='sample_submission.csv.7z':
            # !p7zip -d 'sample_submission.csv.7z'
            print("="*50)
            print("'{}' File Extracted Successfully".format(file))

        print("="*50)
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 474092593 bytes (453 MiB)
#
# Extracting archive: train.csv.7z
# --
# Path = train.csv.7z
# Type = 7z
# Physical Size = 474092593
# Headers Size = 122
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       4997452288
# Compressed: 474092593
# ==================================================
# 'train.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 4885065 bytes (4771 KiB)
#
# Extracting archive: test.csv.7z
# --
# Path = test.csv.7z
# Type = 7z
# Physical Size = 4885065
# Headers Size = 122
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       126163026
# Compressed: 4885065
# ==================================================
# 'test.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 3762 bytes (4 KiB)
#
# Extracting archive: oil.csv.7z
# --
# Path = oil.csv.7z
# Type = 7z
# Physical Size = 3762
# Headers Size = 122
# Method = LZMA2:24k
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       20580
# Compressed: 3762
# ==================================================
# 'oil.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 219499 bytes (215 KiB)
#
# Extracting archive: transactions.csv.7z
# --
# Path = transactions.csv.7z
# Type = 7z
# Physical Size = 219499
# Headers Size = 138
# Method = LZMA2:1536k
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       1552637
# Compressed: 219499
# ==================================================
# 'transactions.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 14315 bytes (14 KiB)
#
# Extracting archive: items.csv.7z
# --
# Path = items.csv.7z
# Type = 7z
# Physical Size = 14315
# Headers Size = 122
# Method = LZMA2:17
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       101841
# Compressed: 14315
# ==================================================
# 'items.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1898 bytes (2 KiB)
#
# Extracting archive: holidays_events.csv.7z
# --
# Path = holidays_events.csv.7z
# Type = 7z
# Physical Size = 1898
# Headers Size = 146
# Method = LZMA2:24k
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       22309
# Compressed: 1898
# ==================================================
# 'holidays_events.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 648 bytes (1 KiB)
#
# Extracting archive: stores.csv.7z
# --
# Path = stores.csv.7z
# Type = 7z
# Physical Size = 648
# Headers Size = 130
# Method = LZMA2:12
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       1387
# Compressed: 648
# ==================================================
# 'stores.csv.7z' File Extracted Successfully
# ==================================================
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 666528 bytes (651 KiB)
#
# Extracting archive: sample_submission.csv.7z
# --
# Path = sample_submission.csv.7z
# Type = 7z
# Physical Size = 666528
# Headers Size = 146
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       40445582
# Compressed: 666528
# ==================================================
# 'sample_submission.csv.7z' File Extracted Successfully
# ==================================================

# %%
#Creating features by excecuting Pre_Processing Feature_engineering.py

exec(open('Pre_Processing Feature_engineering.py').read())

# Train Dataset Initial Date 28/6/2017
# 2 weeks

# Validation Dataset Initial Date 26/7/2017
# 1 week

# Test Dataset Initial Date 16/8/2017
# 1 week
# Out:
# Data Pre-Processing ...
# HBox(children=(FloatProgress(value=0.0, max=23808261.0), HTML(value='')))
# Enter the following for Train Data :
#
# Starting Date (Day/Month/Year) --> 28/6/2017
# No. of weeks --> 2
#
# Creating Features for data between Dates --> 2017-06-28 - 2017-07-12 (i.e. 2 weeks)
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# Saving 'X_train.csv' File ...
# Saving 'y_train.csv' File ...
#
# Enter the following for Validation Data :
#
# Starting Date (Day/Month/Year) --> 26/7/2017
# No. of weeks --> 1
#
# Creating Features for data between Dates --> 2017-07-26 - 2017-08-02 (i.e. 1 weeks)
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Saving 'X_val.csv' File ...
# Saving 'y_val.csv' File ...
#
# Enter the following for Test Data :
#
# Starting Date (Day/Month/Year) --> 16/8/2017
# No. of weeks --> 1
#
# Creating Features for data between Dates --> 2017-08-16 - 2017-08-23 (i.e. 1 weeks)
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Saving 'X_test.csv' File ...
#
# Saving 'sales_2017.csv' File ...
# Saving 'stores_items.csv' File ...

# %% [markdown]
# ### Reading Data

# %%
# Reading X_train.csv and reducing memory usage
X_train=pd.read_csv("X_train.csv")
X_train=reduce_mem_usage(X_train)

# Reading y_train.csv and converting into numpy array
y_train = np.array(pd.read_csv( 'y_train.csv'))
# Out:
# Memory usage of Dataframe is 4853.989 MB
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# Memory usage after optimization is: 1054.381 MB
# Decreased by 78.3%

# %%
# Reading X_val.csv and reducing memory usage
X_val=pd.read_csv("X_val.csv")
X_val=reduce_mem_usage(X_val)

# Reading y_val.csv and converting into numpy array
y_val = np.array(pd.read_csv( 'y_val.csv'))
# Out:
# Memory usage of Dataframe is 808.998 MB
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# Memory usage after optimization is: 175.091 MB
# Decreased by 78.4%

# %%
# Reading X_test.csv and reducing memory usage
X_test=pd.read_csv("X_test.csv")
X_test=reduce_mem_usage(X_test)
# Out:
# Memory usage of Dataframe is 808.998 MB
# HBox(children=(FloatProgress(value=0.0, max=633.0), HTML(value='')))
# Memory usage after optimization is: 175.730 MB
# Decreased by 78.3%

# %%
# Reading stores_items.csv
stores_items = pd.read_csv('stores_items.csv', index_col=['store_nbr','item_nbr'])

# Reading items.csv and setting index as item_nbr
items = pd.read_csv( 'items.csv' ).set_index("item_nbr")

items = items.reindex( stores_items.index.get_level_values(1) )
items=reduce_mem_usage(items)
# Out:
# Memory usage of Dataframe is 5.112 MB
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Memory usage after optimization is: 1.919 MB
# Decreased by 62.5%

# %% [markdown]
# ### Feature Selection

# %%
# Loading Top 300 Feature Names (got by training random forest)
import pickle
with open('300_filtered_features.pkl','rb') as file:
    filtered_features = pickle.load( file)

# %% [markdown]
# ### Defining XGBOOST

# %%
def train_xgb_model(X_train,y_train,X_val,y_val,params,num_boost_rounds,n_days,items,features,X_test=None):
    '''
    Filter features from the Dataset and then
    Trains 16 different xgb models for predicting next 16 days sales . 

    Returns --> * val_pred i.e.predicted values of validation data
                * test_pred i.e.predicted values of test data if present
    '''
    params['objective'] = 'reg:squarederror'
    params['eval_metric'] = 'rmse'
    params['tree_method'] ='gpu_hist'

    val_pred = []
    test_pred = []

    #Training 16 different models for predicting next 16 days sales.
    for i in range(16):
        print("=" * 50)
        print("Step %d" % (i+1))
        print("=" * 50)

        # Filtering features
        x_train = X_train[features[i]]
        x_val = X_val[features[i]]

        #Filtering Features from test dataset if it exists.
        try:
            x_test = X_test[features[i]]
        except:
            pass

        #Creating Train Dmatrix (DMatrix is a internal data structure that used by XGBoost which is optimized for both memory efficiency and training speed.)
        dtrain = xgb.DMatrix( x_train, label=y_train[:, i],
                              weight=pd.concat([items["perishable"]] * n_days) * 0.25 + 1)
        
        #Creating Validation Dmatrix
        dval = xgb.DMatrix( x_val, label=y_val[:, i],
                            weight=items["perishable"] * 0.25 + 1)
        
        # watchist is used to see the evaluation metrics of the datasets given while training
        watchlist = [ (dtrain,'train'), (dval,'val') ]

        #Training Xgboost
        model = xgb.train(params, dtrain, num_boost_rounds, watchlist, early_stopping_rounds=125, verbose_eval=50)

        # appending results of prediction on val set
        val_pred.append(model.predict(xgb.DMatrix(x_val), ntree_limit = model.best_ntree_limit  or num_boost_rounds))

        # appending results of prediction on test set if it exists
        try:
            test_pred.append(model.predict(xgb.DMatrix(x_test), ntree_limit = model.best_ntree_limit  or num_boost_rounds))
        except:
            pass

        # Deleting unneccessary variables
        del model,dtrain,dval,x_train,x_val

    if type(X_test) != type(None):
        return val_pred,test_pred
    else:
        return val_pred

# %% [markdown]
# ### Performance Metric

# %% [markdown]
# **NWRMSLE** (Normalized Weighted Root Mean Squared Logarithmic Error)

# %%
def calculate_nwrmsle(true,pred,weight):
    ''' 
    Calculates Normalized Weighted Root Mean Squared Logarithmic Error (nwrmsle)

    true = true labels
    pred =  predicted labels
    weight = weights of datapoints

    returns nwrmsle '''

    temp = (true - np.array(pred).transpose())**2
    temp = temp.sum(axis=1) * weight
    nwrmsle = np.sqrt(temp.sum() / weight.sum() / 16)
    return nwrmsle

# %% [markdown]
# ### HyperParameter Tuning (Using gp minimize)

# %%
# function to fit the model and return the performance of the model
def return_model_assessment(args, X_train, y_train, X_val, y_val, model, n_days ,items , features ,num_boost_rounds =None):
    global model_hyper_params,count
    count+=1
    print('='*50)
    print("\nTraining Model No. {} ...".format(count))
    params = {model_hyper_params[i]: args[i] for i, j in enumerate(model_hyper_params)}
    print("Parameters --> ",params)


    if model=='xgb':
        val_pred = train_xgb_model(X_train,y_train,X_val,y_val,params,num_boost_rounds,n_days,items,features)

    elif model=='lgb':
        val_pred = train_lgb_model(X_train,y_train,X_val,y_val,params,num_boost_rounds,n_days,items,features)

    elif model== 'rf' :
        val_pred = train_rf_model(X_train,y_train,X_val,y_val,params,n_days,items,features)

    #calculating nwrmsle
    weight = items["perishable"] * 0.25 + 1
    nwrmsle = calculate_nwrmsle(y_val, y_pred, weight)

    return nwrmsle      #returning nwrmsle because we want to minimize it.

# %%
# %%time

# defining space for searching optimal parameters
space = [
    Real(0.4, 0.8, name="colsample_bytree"),
    Real(0.01, 0.5, name="gamma"),
    Real(0.001, 0.1,"log-uniform",  name="eta"),
    Integer(3, 10, name="max_depth"),
    Integer(1, 5, name="min_child_weight"),
    Real(0.4, 0.8, name="subsample"),
    ]
# Using high no. of trees (i.e. 2000) to get better model performance with early stopping.
boost_rounds = 2000

count=0
model_hyper_params = [ 'colsample_bytree', 'gamma', 'eta', 'max_depth', 'min_child_weight', 'subsample']

# Objective function which will return nwrmsle .
objective_function = partial(return_model_assessment,
                             X_train=X_train, y_train=y_train, X_val = X_val,y_val= y_val ,
                             model='xgb', n_days=2, items=items , 
                             features= filtered_features,num_boost_rounds= boost_rounds)

# Running the algorithm
n_calls = 10 # number of times to train model
results = gp_minimize(objective_function, space, base_estimator=None, n_calls=n_calls, n_random_starts=n_calls-1, random_state=42)
# Out:
# Streaming output truncated to the last 5000 lines.
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.559761	val-rmse:0.604931
# [100]	train-rmse:0.544085	val-rmse:0.602832
# [150]	train-rmse:0.533509	val-rmse:0.603253
# [200]	train-rmse:0.524922	val-rmse:0.603916
# Stopping. Best iteration:
# [106]	train-rmse:0.542633	val-rmse:0.602777
#
# ==================================================
# Step 11
# ==================================================
# [0]	train-rmse:1.20914	val-rmse:1.20593
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.573634	val-rmse:0.610328
# [100]	train-rmse:0.557116	val-rmse:0.608409
# [150]	train-rmse:0.546135	val-rmse:0.608551
# [200]	train-rmse:0.537069	val-rmse:0.608892
# Stopping. Best iteration:
# [105]	train-rmse:0.555661	val-rmse:0.608264
#
# ==================================================
# Step 12
# ==================================================
# [0]	train-rmse:1.26137	val-rmse:1.2434
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.579629	val-rmse:0.617197
# [100]	train-rmse:0.56205	val-rmse:0.614854
# [150]	train-rmse:0.550043	val-rmse:0.615691
# [200]	train-rmse:0.54008	val-rmse:0.616105
# Stopping. Best iteration:
# [111]	train-rmse:0.558889	val-rmse:0.61472
#
# ==================================================
# Step 13
# ==================================================
# [0]	train-rmse:1.11506	val-rmse:1.11349
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.576526	val-rmse:0.614345
# [100]	train-rmse:0.561261	val-rmse:0.613461
# [150]	train-rmse:0.550389	val-rmse:0.613959
# [200]	train-rmse:0.541212	val-rmse:0.614973
# Stopping. Best iteration:
# [76]	train-rmse:0.567533	val-rmse:0.61325
#
# ==================================================
# Step 14
# ==================================================
# [0]	train-rmse:1.07151	val-rmse:1.07045
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.566229	val-rmse:0.600977
# [100]	train-rmse:0.551785	val-rmse:0.600509
# [150]	train-rmse:0.541329	val-rmse:0.602178
# [200]	train-rmse:0.532537	val-rmse:0.602578
# Stopping. Best iteration:
# [95]	train-rmse:0.553026	val-rmse:0.600406
#
# ==================================================
# Step 15
# ==================================================
# [0]	train-rmse:1.08334	val-rmse:1.07387
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.55712	val-rmse:0.587248
# [100]	train-rmse:0.542192	val-rmse:0.585993
# [150]	train-rmse:0.531554	val-rmse:0.586211
# [200]	train-rmse:0.523233	val-rmse:0.586745
# Stopping. Best iteration:
# [98]	train-rmse:0.542624	val-rmse:0.585939
#
# ==================================================
# Step 16
# ==================================================
# [0]	train-rmse:1.02642	val-rmse:1.02461
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.568139	val-rmse:0.607852
# [100]	train-rmse:0.553146	val-rmse:0.607665
# [150]	train-rmse:0.54324	val-rmse:0.608207
# [200]	train-rmse:0.533652	val-rmse:0.608838
# Stopping. Best iteration:
# [77]	train-rmse:0.559018	val-rmse:0.607382
#
# ==================================================
#
# Training Model No. 4 ...
# Parameters -->  {'colsample_bytree': 0.4092249700165663, 'gamma': 0.2671395835266107, 'eta': 0.006305535040199288, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.49310853617212175}
# ==================================================
# Step 1
# ==================================================
# [0]	train-rmse:1.18368	val-rmse:1.14159
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.957495	val-rmse:0.922857
# [100]	train-rmse:0.810351	val-rmse:0.782424
# [150]	train-rmse:0.715849	val-rmse:0.693839
# [200]	train-rmse:0.657431	val-rmse:0.640232
# [250]	train-rmse:0.621605	val-rmse:0.608231
# [300]	train-rmse:0.599617	val-rmse:0.589109
# [350]	train-rmse:0.585401	val-rmse:0.576999
# [400]	train-rmse:0.576539	val-rmse:0.569757
# [450]	train-rmse:0.570331	val-rmse:0.564751
# [500]	train-rmse:0.565782	val-rmse:0.561119
# [550]	train-rmse:0.56212	val-rmse:0.558169
# [600]	train-rmse:0.55955	val-rmse:0.556099
# [650]	train-rmse:0.557499	val-rmse:0.554525
# [700]	train-rmse:0.555815	val-rmse:0.553143
# [750]	train-rmse:0.554257	val-rmse:0.551889
# [800]	train-rmse:0.552977	val-rmse:0.550862
# [850]	train-rmse:0.551986	val-rmse:0.550096
# [900]	train-rmse:0.551032	val-rmse:0.549331
# [950]	train-rmse:0.550312	val-rmse:0.548806
# [1000]	train-rmse:0.549637	val-rmse:0.548281
# [1050]	train-rmse:0.549022	val-rmse:0.547798
# [1100]	train-rmse:0.548442	val-rmse:0.547318
# [1150]	train-rmse:0.547908	val-rmse:0.546867
# [1200]	train-rmse:0.547454	val-rmse:0.546526
# [1250]	train-rmse:0.547036	val-rmse:0.546191
# [1300]	train-rmse:0.54659	val-rmse:0.545821
# [1350]	train-rmse:0.546227	val-rmse:0.545569
# [1400]	train-rmse:0.545805	val-rmse:0.545237
# [1450]	train-rmse:0.545457	val-rmse:0.544942
# [1500]	train-rmse:0.545138	val-rmse:0.544724
# [1550]	train-rmse:0.544832	val-rmse:0.544479
# [1600]	train-rmse:0.544516	val-rmse:0.544237
# [1650]	train-rmse:0.54424	val-rmse:0.544051
# [1700]	train-rmse:0.543926	val-rmse:0.543809
# [1750]	train-rmse:0.543638	val-rmse:0.543601
# [1800]	train-rmse:0.543368	val-rmse:0.543401
# [1850]	train-rmse:0.543102	val-rmse:0.543224
# [1900]	train-rmse:0.542821	val-rmse:0.54298
# [1950]	train-rmse:0.542585	val-rmse:0.542829
# [1999]	train-rmse:0.542326	val-rmse:0.54262
# ==================================================
# Step 2
# ==================================================
# [0]	train-rmse:1.1005	val-rmse:1.0754
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.903543	val-rmse:0.886635
# [100]	train-rmse:0.777205	val-rmse:0.767492
# [150]	train-rmse:0.698076	val-rmse:0.694285
# [200]	train-rmse:0.64935	val-rmse:0.650299
# [250]	train-rmse:0.620215	val-rmse:0.624318
# [300]	train-rmse:0.60268	val-rmse:0.608907
# [350]	train-rmse:0.591802	val-rmse:0.599418
# [400]	train-rmse:0.584686	val-rmse:0.593284
# [450]	train-rmse:0.579954	val-rmse:0.589205
# [500]	train-rmse:0.576565	val-rmse:0.586371
# [550]	train-rmse:0.573757	val-rmse:0.583972
# [600]	train-rmse:0.571736	val-rmse:0.582296
# [650]	train-rmse:0.570112	val-rmse:0.580931
# [700]	train-rmse:0.568779	val-rmse:0.579734
# [750]	train-rmse:0.567691	val-rmse:0.578777
# [800]	train-rmse:0.566755	val-rmse:0.577954
# [850]	train-rmse:0.565976	val-rmse:0.577297
# [900]	train-rmse:0.565237	val-rmse:0.576625
# [950]	train-rmse:0.564567	val-rmse:0.57603
# [1000]	train-rmse:0.564009	val-rmse:0.575576
# [1050]	train-rmse:0.563453	val-rmse:0.575039
# [1100]	train-rmse:0.562966	val-rmse:0.574611
# [1150]	train-rmse:0.562529	val-rmse:0.574301
# [1200]	train-rmse:0.562106	val-rmse:0.573914
# [1250]	train-rmse:0.561745	val-rmse:0.573626
# [1300]	train-rmse:0.56139	val-rmse:0.573354
# [1350]	train-rmse:0.561014	val-rmse:0.573032
# [1400]	train-rmse:0.560699	val-rmse:0.572809
# [1450]	train-rmse:0.560431	val-rmse:0.572613
# [1500]	train-rmse:0.560155	val-rmse:0.572404
# [1550]	train-rmse:0.559897	val-rmse:0.572225
# [1600]	train-rmse:0.559623	val-rmse:0.572055
# [1650]	train-rmse:0.559343	val-rmse:0.571827
# [1700]	train-rmse:0.55911	val-rmse:0.571635
# [1750]	train-rmse:0.558878	val-rmse:0.57147
# [1800]	train-rmse:0.558663	val-rmse:0.57135
# [1850]	train-rmse:0.55843	val-rmse:0.571164
# [1900]	train-rmse:0.558215	val-rmse:0.571018
# [1950]	train-rmse:0.558003	val-rmse:0.570859
# [1999]	train-rmse:0.55781	val-rmse:0.570744
# ==================================================
# Step 3
# ==================================================
# [0]	train-rmse:1.18921	val-rmse:1.18868
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.966159	val-rmse:0.97222
# [100]	train-rmse:0.82156	val-rmse:0.833226
# [150]	train-rmse:0.729362	val-rmse:0.745172
# [200]	train-rmse:0.672374	val-rmse:0.690822
# [250]	train-rmse:0.637827	val-rmse:0.657619
# [300]	train-rmse:0.616798	val-rmse:0.637278
# [350]	train-rmse:0.603771	val-rmse:0.624588
# [400]	train-rmse:0.594987	val-rmse:0.615958
# [450]	train-rmse:0.588621	val-rmse:0.609655
# [500]	train-rmse:0.583684	val-rmse:0.604831
# [550]	train-rmse:0.58019	val-rmse:0.601414
# [600]	train-rmse:0.57743	val-rmse:0.598862
# [650]	train-rmse:0.575152	val-rmse:0.596771
# [700]	train-rmse:0.573294	val-rmse:0.595085
# [750]	train-rmse:0.571746	val-rmse:0.593742
# [800]	train-rmse:0.570462	val-rmse:0.592664
# [850]	train-rmse:0.569368	val-rmse:0.591758
# [900]	train-rmse:0.568363	val-rmse:0.590938
# [950]	train-rmse:0.567501	val-rmse:0.590298
# [1000]	train-rmse:0.566632	val-rmse:0.589593
# [1050]	train-rmse:0.565983	val-rmse:0.589161
# [1100]	train-rmse:0.565322	val-rmse:0.588722
# [1150]	train-rmse:0.56472	val-rmse:0.588305
# [1200]	train-rmse:0.564195	val-rmse:0.587929
# [1250]	train-rmse:0.563657	val-rmse:0.587515
# [1300]	train-rmse:0.563185	val-rmse:0.587244
# [1350]	train-rmse:0.562701	val-rmse:0.586952
# [1400]	train-rmse:0.562248	val-rmse:0.58668
# [1450]	train-rmse:0.561853	val-rmse:0.58646
# [1500]	train-rmse:0.561449	val-rmse:0.58619
# [1550]	train-rmse:0.561076	val-rmse:0.585957
# [1600]	train-rmse:0.560717	val-rmse:0.585728
# [1650]	train-rmse:0.560376	val-rmse:0.585517
# [1700]	train-rmse:0.560064	val-rmse:0.585326
# [1750]	train-rmse:0.559736	val-rmse:0.585109
# [1800]	train-rmse:0.559448	val-rmse:0.584915
# [1850]	train-rmse:0.559165	val-rmse:0.584726
# [1900]	train-rmse:0.558883	val-rmse:0.58454
# [1950]	train-rmse:0.558597	val-rmse:0.584368
# [1999]	train-rmse:0.55832	val-rmse:0.584187
# ==================================================
# Step 4
# ==================================================
# [0]	train-rmse:1.36739	val-rmse:1.3047
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:1.09063	val-rmse:1.03797
# [100]	train-rmse:0.907346	val-rmse:0.865007
# [150]	train-rmse:0.790215	val-rmse:0.758168
# [200]	train-rmse:0.717489	val-rmse:0.695394
# [250]	train-rmse:0.67326	val-rmse:0.659905
# [300]	train-rmse:0.646542	val-rmse:0.640016
# [350]	train-rmse:0.630466	val-rmse:0.628945
# [400]	train-rmse:0.620304	val-rmse:0.622544
# [450]	train-rmse:0.613466	val-rmse:0.618411
# [500]	train-rmse:0.608297	val-rmse:0.615046
# [550]	train-rmse:0.604527	val-rmse:0.612842
# [600]	train-rmse:0.60162	val-rmse:0.611075
# [650]	train-rmse:0.599223	val-rmse:0.609585
# [700]	train-rmse:0.597177	val-rmse:0.608321
# [750]	train-rmse:0.595495	val-rmse:0.607403
# [800]	train-rmse:0.593991	val-rmse:0.606525
# [850]	train-rmse:0.592665	val-rmse:0.605786
# [900]	train-rmse:0.591443	val-rmse:0.604979
# [950]	train-rmse:0.590342	val-rmse:0.604272
# [1000]	train-rmse:0.589324	val-rmse:0.603524
# [1050]	train-rmse:0.588463	val-rmse:0.602982
# [1100]	train-rmse:0.587656	val-rmse:0.602454
# [1150]	train-rmse:0.586896	val-rmse:0.601932
# [1200]	train-rmse:0.58621	val-rmse:0.601511
# [1250]	train-rmse:0.585562	val-rmse:0.601068
# [1300]	train-rmse:0.584883	val-rmse:0.600531
# [1350]	train-rmse:0.584258	val-rmse:0.600052
# [1400]	train-rmse:0.583745	val-rmse:0.599709
# [1450]	train-rmse:0.583194	val-rmse:0.599366
# [1500]	train-rmse:0.582705	val-rmse:0.599029
# [1550]	train-rmse:0.582237	val-rmse:0.598714
# [1600]	train-rmse:0.581784	val-rmse:0.598429
# [1650]	train-rmse:0.581379	val-rmse:0.598195
# [1700]	train-rmse:0.580981	val-rmse:0.597965
# [1750]	train-rmse:0.580606	val-rmse:0.597769
# [1800]	train-rmse:0.580225	val-rmse:0.597514
# [1850]	train-rmse:0.579861	val-rmse:0.597329
# [1900]	train-rmse:0.579555	val-rmse:0.597183
# [1950]	train-rmse:0.579223	val-rmse:0.597013
# [1999]	train-rmse:0.578907	val-rmse:0.59684
# ==================================================
# Step 5
# ==================================================
# [0]	train-rmse:1.41095	val-rmse:1.3463
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:1.12404	val-rmse:1.06804
# [100]	train-rmse:0.933608	val-rmse:0.886702
# [150]	train-rmse:0.81129	val-rmse:0.774064
# [200]	train-rmse:0.734823	val-rmse:0.70662
# [250]	train-rmse:0.687797	val-rmse:0.668056
# [300]	train-rmse:0.659307	val-rmse:0.646267
# [350]	train-rmse:0.641891	val-rmse:0.634152
# [400]	train-rmse:0.631031	val-rmse:0.627343
# [450]	train-rmse:0.623891	val-rmse:0.623063
# [500]	train-rmse:0.61833	val-rmse:0.619351
# [550]	train-rmse:0.614193	val-rmse:0.616629
# [600]	train-rmse:0.610936	val-rmse:0.614487
# [650]	train-rmse:0.608305	val-rmse:0.612713
# [700]	train-rmse:0.606198	val-rmse:0.611467
# [750]	train-rmse:0.604412	val-rmse:0.610381
# [800]	train-rmse:0.602835	val-rmse:0.609421
# [850]	train-rmse:0.601493	val-rmse:0.608519
# [900]	train-rmse:0.600161	val-rmse:0.607554
# [950]	train-rmse:0.599053	val-rmse:0.606787
# [1000]	train-rmse:0.597947	val-rmse:0.606007
# [1050]	train-rmse:0.597019	val-rmse:0.605512
# [1100]	train-rmse:0.596108	val-rmse:0.604845
# [1150]	train-rmse:0.595219	val-rmse:0.604218
# [1200]	train-rmse:0.594431	val-rmse:0.603708
# [1250]	train-rmse:0.593713	val-rmse:0.603157
# [1300]	train-rmse:0.592914	val-rmse:0.602539
# [1350]	train-rmse:0.592258	val-rmse:0.602116
# [1400]	train-rmse:0.591652	val-rmse:0.601749
# [1450]	train-rmse:0.591107	val-rmse:0.601415
# [1500]	train-rmse:0.590534	val-rmse:0.60102
# [1550]	train-rmse:0.589951	val-rmse:0.600615
# [1600]	train-rmse:0.589499	val-rmse:0.600394
# [1650]	train-rmse:0.589073	val-rmse:0.600169
# [1700]	train-rmse:0.58855	val-rmse:0.599787
# [1750]	train-rmse:0.588121	val-rmse:0.599507
# [1800]	train-rmse:0.587697	val-rmse:0.59922
# [1850]	train-rmse:0.587276	val-rmse:0.598944
# [1900]	train-rmse:0.586882	val-rmse:0.59873
# [1950]	train-rmse:0.586526	val-rmse:0.598536
# [1999]	train-rmse:0.586179	val-rmse:0.598292
# ==================================================
# Step 6
# ==================================================
# [0]	train-rmse:1.231	val-rmse:1.23181
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:1.00003	val-rmse:1.004
# [100]	train-rmse:0.851151	val-rmse:0.856485
# [150]	train-rmse:0.757455	val-rmse:0.76328
# [200]	train-rmse:0.700015	val-rmse:0.706003
# [250]	train-rmse:0.665468	val-rmse:0.671848
# [300]	train-rmse:0.644577	val-rmse:0.650806
# [350]	train-rmse:0.631739	val-rmse:0.637815
# [400]	train-rmse:0.623342	val-rmse:0.629584
# [450]	train-rmse:0.617497	val-rmse:0.623953
# [500]	train-rmse:0.612978	val-rmse:0.619432
# [550]	train-rmse:0.609744	val-rmse:0.616334
# [600]	train-rmse:0.607205	val-rmse:0.613959
# [650]	train-rmse:0.605153	val-rmse:0.612107
# [700]	train-rmse:0.60349	val-rmse:0.610664
# [750]	train-rmse:0.602088	val-rmse:0.60946
# [800]	train-rmse:0.600942	val-rmse:0.608522
# [850]	train-rmse:0.59988	val-rmse:0.607749
# [900]	train-rmse:0.598883	val-rmse:0.60695
# [950]	train-rmse:0.598053	val-rmse:0.606309
# [1000]	train-rmse:0.59729	val-rmse:0.60567
# [1050]	train-rmse:0.596614	val-rmse:0.605182
# [1100]	train-rmse:0.595975	val-rmse:0.604781
# [1150]	train-rmse:0.595389	val-rmse:0.604428
# [1200]	train-rmse:0.594847	val-rmse:0.60404
# [1250]	train-rmse:0.594399	val-rmse:0.603734
# [1300]	train-rmse:0.593888	val-rmse:0.603383
# [1350]	train-rmse:0.593448	val-rmse:0.60305
# [1400]	train-rmse:0.59301	val-rmse:0.602729
# [1450]	train-rmse:0.592612	val-rmse:0.602464
# [1500]	train-rmse:0.592239	val-rmse:0.602235
# [1550]	train-rmse:0.591858	val-rmse:0.602032
# [1600]	train-rmse:0.591529	val-rmse:0.6018
# [1650]	train-rmse:0.591198	val-rmse:0.601612
# [1700]	train-rmse:0.590852	val-rmse:0.601412
# [1750]	train-rmse:0.590525	val-rmse:0.601172
# [1800]	train-rmse:0.590203	val-rmse:0.600978
# [1850]	train-rmse:0.589889	val-rmse:0.600793
# [1900]	train-rmse:0.589615	val-rmse:0.600654
# [1950]	train-rmse:0.589337	val-rmse:0.600511
# [1999]	train-rmse:0.589059	val-rmse:0.600326
# ==================================================
# Step 7
# ==================================================
# [0]	train-rmse:1.18156	val-rmse:1.29133
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.968108	val-rmse:1.07428
# [100]	train-rmse:0.830594	val-rmse:0.930897
# [150]	train-rmse:0.74359	val-rmse:0.836159
# [200]	train-rmse:0.690586	val-rmse:0.774627
# [250]	train-rmse:0.658782	val-rmse:0.735144
# [300]	train-rmse:0.639145	val-rmse:0.709274
# [350]	train-rmse:0.62651	val-rmse:0.691707
# [400]	train-rmse:0.61807	val-rmse:0.68008
# [450]	train-rmse:0.612294	val-rmse:0.671761
# [500]	train-rmse:0.607911	val-rmse:0.666021
# [550]	train-rmse:0.604751	val-rmse:0.661807
# [600]	train-rmse:0.602236	val-rmse:0.65882
# [650]	train-rmse:0.600181	val-rmse:0.656829
# [700]	train-rmse:0.598485	val-rmse:0.655317
# [750]	train-rmse:0.597022	val-rmse:0.653955
# [800]	train-rmse:0.595798	val-rmse:0.652975
# [850]	train-rmse:0.594752	val-rmse:0.652128
# [900]	train-rmse:0.59385	val-rmse:0.651489
# [950]	train-rmse:0.593014	val-rmse:0.650797
# [1000]	train-rmse:0.592284	val-rmse:0.650357
# [1050]	train-rmse:0.59156	val-rmse:0.649792
# [1100]	train-rmse:0.590923	val-rmse:0.649374
# [1150]	train-rmse:0.59032	val-rmse:0.649005
# [1200]	train-rmse:0.589779	val-rmse:0.648798
# [1250]	train-rmse:0.589232	val-rmse:0.648458
# [1300]	train-rmse:0.588745	val-rmse:0.648135
# [1350]	train-rmse:0.58827	val-rmse:0.647786
# [1400]	train-rmse:0.587857	val-rmse:0.647537
# [1450]	train-rmse:0.587459	val-rmse:0.647293
# [1500]	train-rmse:0.587031	val-rmse:0.647079
# [1550]	train-rmse:0.586686	val-rmse:0.646926
# [1600]	train-rmse:0.586323	val-rmse:0.646769
# [1650]	train-rmse:0.585916	val-rmse:0.646476
# [1700]	train-rmse:0.585542	val-rmse:0.646336
# [1750]	train-rmse:0.585218	val-rmse:0.646123
# [1800]	train-rmse:0.584912	val-rmse:0.645868
# [1850]	train-rmse:0.584611	val-rmse:0.645662
# [1900]	train-rmse:0.584298	val-rmse:0.645412
# [1950]	train-rmse:0.583996	val-rmse:0.645155
# [1999]	train-rmse:0.583708	val-rmse:0.644988
# ==================================================
# Step 8
# ==================================================
# [0]	train-rmse:1.18752	val-rmse:1.27152
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.970172	val-rmse:1.05333
# [100]	train-rmse:0.829316	val-rmse:0.908867
# [150]	train-rmse:0.739505	val-rmse:0.813779
# [200]	train-rmse:0.684353	val-rmse:0.752544
# [250]	train-rmse:0.650643	val-rmse:0.712859
# [300]	train-rmse:0.629222	val-rmse:0.686683
# [350]	train-rmse:0.615681	val-rmse:0.669309
# [400]	train-rmse:0.606806	val-rmse:0.65714
# [450]	train-rmse:0.600805	val-rmse:0.648908
# [500]	train-rmse:0.595933	val-rmse:0.642643
# [550]	train-rmse:0.592496	val-rmse:0.638153
# [600]	train-rmse:0.589771	val-rmse:0.634893
# [650]	train-rmse:0.587507	val-rmse:0.632494
# [700]	train-rmse:0.58564	val-rmse:0.630649
# [750]	train-rmse:0.583973	val-rmse:0.629115
# [800]	train-rmse:0.582635	val-rmse:0.627902
# [850]	train-rmse:0.581482	val-rmse:0.626917
# [900]	train-rmse:0.580474	val-rmse:0.626188
# [950]	train-rmse:0.579576	val-rmse:0.625618
# [1000]	train-rmse:0.57868	val-rmse:0.625068
# [1050]	train-rmse:0.577993	val-rmse:0.624689
# [1100]	train-rmse:0.577306	val-rmse:0.624325
# [1150]	train-rmse:0.576715	val-rmse:0.623908
# [1200]	train-rmse:0.576166	val-rmse:0.623557
# [1250]	train-rmse:0.575641	val-rmse:0.623207
# [1300]	train-rmse:0.575135	val-rmse:0.622857
# [1350]	train-rmse:0.574583	val-rmse:0.622517
# [1400]	train-rmse:0.574132	val-rmse:0.622313
# [1450]	train-rmse:0.573716	val-rmse:0.622086
# [1500]	train-rmse:0.573312	val-rmse:0.621878
# [1550]	train-rmse:0.572905	val-rmse:0.62158
# [1600]	train-rmse:0.572515	val-rmse:0.62134
# [1650]	train-rmse:0.572174	val-rmse:0.621109
# [1700]	train-rmse:0.571772	val-rmse:0.620877
# [1750]	train-rmse:0.571421	val-rmse:0.620564
# [1800]	train-rmse:0.57109	val-rmse:0.620339
# [1850]	train-rmse:0.570749	val-rmse:0.62006
# [1900]	train-rmse:0.570436	val-rmse:0.619867
# [1950]	train-rmse:0.57012	val-rmse:0.619651
# [1999]	train-rmse:0.569806	val-rmse:0.619478
# ==================================================
# Step 9
# ==================================================
# [0]	train-rmse:1.097	val-rmse:1.14245
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.911772	val-rmse:0.956763
# [100]	train-rmse:0.792655	val-rmse:0.836094
# [150]	train-rmse:0.717893	val-rmse:0.75867
# [200]	train-rmse:0.672326	val-rmse:0.709935
# [250]	train-rmse:0.645059	val-rmse:0.67942
# [300]	train-rmse:0.628168	val-rmse:0.659976
# [350]	train-rmse:0.617684	val-rmse:0.647452
# [400]	train-rmse:0.610475	val-rmse:0.639056
# [450]	train-rmse:0.605508	val-rmse:0.633378
# [500]	train-rmse:0.601702	val-rmse:0.629316
# [550]	train-rmse:0.598958	val-rmse:0.626472
# [600]	train-rmse:0.596698	val-rmse:0.624487
# [650]	train-rmse:0.594961	val-rmse:0.622951
# [700]	train-rmse:0.593359	val-rmse:0.621695
# [750]	train-rmse:0.592043	val-rmse:0.620774
# [800]	train-rmse:0.591025	val-rmse:0.620004
# [850]	train-rmse:0.590105	val-rmse:0.619437
# [900]	train-rmse:0.589313	val-rmse:0.618998
# [950]	train-rmse:0.588541	val-rmse:0.618624
# [1000]	train-rmse:0.587885	val-rmse:0.618273
# [1050]	train-rmse:0.587239	val-rmse:0.617964
# [1100]	train-rmse:0.586668	val-rmse:0.61767
# [1150]	train-rmse:0.586147	val-rmse:0.617453
# [1200]	train-rmse:0.585671	val-rmse:0.617278
# [1250]	train-rmse:0.585215	val-rmse:0.617049
# [1300]	train-rmse:0.58476	val-rmse:0.616781
# [1350]	train-rmse:0.584304	val-rmse:0.616638
# [1400]	train-rmse:0.583905	val-rmse:0.61648
# [1450]	train-rmse:0.583525	val-rmse:0.616296
# [1500]	train-rmse:0.58312	val-rmse:0.616124
# [1550]	train-rmse:0.582748	val-rmse:0.615968
# [1600]	train-rmse:0.582378	val-rmse:0.615821
# [1650]	train-rmse:0.582056	val-rmse:0.615733
# [1700]	train-rmse:0.58175	val-rmse:0.615564
# [1750]	train-rmse:0.581449	val-rmse:0.615379
# [1800]	train-rmse:0.581164	val-rmse:0.615188
# [1850]	train-rmse:0.580896	val-rmse:0.615041
# [1900]	train-rmse:0.580624	val-rmse:0.614893
# [1950]	train-rmse:0.580356	val-rmse:0.614796
# [1999]	train-rmse:0.580091	val-rmse:0.614672
# ==================================================
# Step 10
# ==================================================
# [0]	train-rmse:1.17523	val-rmse:1.20244
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.967088	val-rmse:0.995594
# [100]	train-rmse:0.831956	val-rmse:0.860581
# [150]	train-rmse:0.746417	val-rmse:0.773815
# [200]	train-rmse:0.693542	val-rmse:0.719615
# [250]	train-rmse:0.660798	val-rmse:0.68531
# [300]	train-rmse:0.640748	val-rmse:0.663608
# [350]	train-rmse:0.628133	val-rmse:0.6497
# [400]	train-rmse:0.619673	val-rmse:0.640367
# [450]	train-rmse:0.613488	val-rmse:0.633684
# [500]	train-rmse:0.608984	val-rmse:0.628965
# [550]	train-rmse:0.60523	val-rmse:0.625472
# [600]	train-rmse:0.602432	val-rmse:0.622866
# [650]	train-rmse:0.600166	val-rmse:0.62087
# [700]	train-rmse:0.598247	val-rmse:0.619373
# [750]	train-rmse:0.596622	val-rmse:0.618082
# [800]	train-rmse:0.595284	val-rmse:0.617091
# [850]	train-rmse:0.594094	val-rmse:0.616272
# [900]	train-rmse:0.593061	val-rmse:0.615538
# [950]	train-rmse:0.592141	val-rmse:0.614852
# [1000]	train-rmse:0.591307	val-rmse:0.61435
# [1050]	train-rmse:0.590498	val-rmse:0.613867
# [1100]	train-rmse:0.589795	val-rmse:0.613467
# [1150]	train-rmse:0.589124	val-rmse:0.613012
# [1200]	train-rmse:0.588477	val-rmse:0.612629
# [1250]	train-rmse:0.587932	val-rmse:0.612278
# [1300]	train-rmse:0.587338	val-rmse:0.611974
# [1350]	train-rmse:0.586803	val-rmse:0.61171
# [1400]	train-rmse:0.586257	val-rmse:0.611464
# [1450]	train-rmse:0.585769	val-rmse:0.61116
# [1500]	train-rmse:0.585285	val-rmse:0.610925
# [1550]	train-rmse:0.584812	val-rmse:0.610629
# [1600]	train-rmse:0.584399	val-rmse:0.610424
# [1650]	train-rmse:0.583953	val-rmse:0.610138
# [1700]	train-rmse:0.583535	val-rmse:0.609896
# [1750]	train-rmse:0.583186	val-rmse:0.609698
# [1800]	train-rmse:0.582801	val-rmse:0.609471
# [1850]	train-rmse:0.582394	val-rmse:0.609251
# [1900]	train-rmse:0.58206	val-rmse:0.609105
# [1950]	train-rmse:0.581723	val-rmse:0.60892
# [1999]	train-rmse:0.581359	val-rmse:0.608741
# ==================================================
# Step 11
# ==================================================
# [0]	train-rmse:1.29828	val-rmse:1.29286
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:1.04967	val-rmse:1.04775
# [100]	train-rmse:0.887563	val-rmse:0.888618
# [150]	train-rmse:0.7843	val-rmse:0.787653
# [200]	train-rmse:0.720469	val-rmse:0.725236
# [250]	train-rmse:0.681187	val-rmse:0.686984
# [300]	train-rmse:0.657527	val-rmse:0.663945
# [350]	train-rmse:0.643029	val-rmse:0.649853
# [400]	train-rmse:0.633891	val-rmse:0.641005
# [450]	train-rmse:0.627485	val-rmse:0.635094
# [500]	train-rmse:0.622896	val-rmse:0.631125
# [550]	train-rmse:0.619245	val-rmse:0.628175
# [600]	train-rmse:0.616559	val-rmse:0.626131
# [650]	train-rmse:0.614402	val-rmse:0.624553
# [700]	train-rmse:0.612544	val-rmse:0.62331
# [750]	train-rmse:0.610908	val-rmse:0.622272
# [800]	train-rmse:0.609563	val-rmse:0.621329
# [850]	train-rmse:0.608421	val-rmse:0.620604
# [900]	train-rmse:0.60737	val-rmse:0.619968
# [950]	train-rmse:0.60645	val-rmse:0.619373
# [1000]	train-rmse:0.605663	val-rmse:0.618874
# [1050]	train-rmse:0.60492	val-rmse:0.618448
# [1100]	train-rmse:0.60419	val-rmse:0.618072
# [1150]	train-rmse:0.603549	val-rmse:0.61772
# [1200]	train-rmse:0.602924	val-rmse:0.617333
# [1250]	train-rmse:0.602349	val-rmse:0.616946
# [1300]	train-rmse:0.601732	val-rmse:0.61664
# [1350]	train-rmse:0.601207	val-rmse:0.616367
# [1400]	train-rmse:0.600642	val-rmse:0.616096
# [1450]	train-rmse:0.600169	val-rmse:0.615861
# [1500]	train-rmse:0.599733	val-rmse:0.615603
# [1550]	train-rmse:0.599273	val-rmse:0.615401
# [1600]	train-rmse:0.598848	val-rmse:0.615201
# [1650]	train-rmse:0.598428	val-rmse:0.614949
# [1700]	train-rmse:0.598032	val-rmse:0.614744
# [1750]	train-rmse:0.597649	val-rmse:0.614568
# [1800]	train-rmse:0.597306	val-rmse:0.614424
# [1850]	train-rmse:0.596964	val-rmse:0.61426
# [1900]	train-rmse:0.596595	val-rmse:0.614054
# [1950]	train-rmse:0.596205	val-rmse:0.613872
# [1999]	train-rmse:0.595886	val-rmse:0.613709
# ==================================================
# Step 12
# ==================================================
# [0]	train-rmse:1.35637	val-rmse:1.33596
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:1.09386	val-rmse:1.07767
# [100]	train-rmse:0.922064	val-rmse:0.909541
# [150]	train-rmse:0.811531	val-rmse:0.802877
# [200]	train-rmse:0.742306	val-rmse:0.737268
# [250]	train-rmse:0.69993	val-rmse:0.697887
# [300]	train-rmse:0.673895	val-rmse:0.674041
# [350]	train-rmse:0.65787	val-rmse:0.659748
# [400]	train-rmse:0.647642	val-rmse:0.651029
# [450]	train-rmse:0.640483	val-rmse:0.645084
# [500]	train-rmse:0.635163	val-rmse:0.6409
# [550]	train-rmse:0.631212	val-rmse:0.638031
# [600]	train-rmse:0.628099	val-rmse:0.635888
# [650]	train-rmse:0.625466	val-rmse:0.634169
# [700]	train-rmse:0.623266	val-rmse:0.632751
# [750]	train-rmse:0.621427	val-rmse:0.631583
# [800]	train-rmse:0.619904	val-rmse:0.630632
# [850]	train-rmse:0.61858	val-rmse:0.629808
# [900]	train-rmse:0.617264	val-rmse:0.629073
# [950]	train-rmse:0.616146	val-rmse:0.628394
# [1000]	train-rmse:0.615102	val-rmse:0.62784
# [1050]	train-rmse:0.614124	val-rmse:0.627292
# [1100]	train-rmse:0.613198	val-rmse:0.626779
# [1150]	train-rmse:0.612364	val-rmse:0.626319
# [1200]	train-rmse:0.611612	val-rmse:0.625928
# [1250]	train-rmse:0.610887	val-rmse:0.625509
# [1300]	train-rmse:0.610209	val-rmse:0.625203
# [1350]	train-rmse:0.609543	val-rmse:0.624883
# [1400]	train-rmse:0.608922	val-rmse:0.624606
# [1450]	train-rmse:0.608359	val-rmse:0.624282
# [1500]	train-rmse:0.607815	val-rmse:0.624008
# [1550]	train-rmse:0.607313	val-rmse:0.623752
# [1600]	train-rmse:0.6068	val-rmse:0.623548
# [1650]	train-rmse:0.606332	val-rmse:0.623309
# [1700]	train-rmse:0.605891	val-rmse:0.623118
# [1750]	train-rmse:0.605417	val-rmse:0.622851
# [1800]	train-rmse:0.604992	val-rmse:0.622617
# [1850]	train-rmse:0.604617	val-rmse:0.622463
# [1900]	train-rmse:0.604198	val-rmse:0.62227
# [1950]	train-rmse:0.603786	val-rmse:0.622087
# [1999]	train-rmse:0.603433	val-rmse:0.621928
# ==================================================
# Step 13
# ==================================================
# [0]	train-rmse:1.19254	val-rmse:1.18872
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.979223	val-rmse:0.979175
# [100]	train-rmse:0.841824	val-rmse:0.844349
# [150]	train-rmse:0.755006	val-rmse:0.759208
# [200]	train-rmse:0.702228	val-rmse:0.7073
# [250]	train-rmse:0.670203	val-rmse:0.676048
# [300]	train-rmse:0.650528	val-rmse:0.656954
# [350]	train-rmse:0.638201	val-rmse:0.645152
# [400]	train-rmse:0.630318	val-rmse:0.63778
# [450]	train-rmse:0.624669	val-rmse:0.632773
# [500]	train-rmse:0.620456	val-rmse:0.629332
# [550]	train-rmse:0.617374	val-rmse:0.626992
# [600]	train-rmse:0.615014	val-rmse:0.625243
# [650]	train-rmse:0.612943	val-rmse:0.623899
# [700]	train-rmse:0.611258	val-rmse:0.622841
# [750]	train-rmse:0.609746	val-rmse:0.621982
# [800]	train-rmse:0.608516	val-rmse:0.62124
# [850]	train-rmse:0.607478	val-rmse:0.620688
# [900]	train-rmse:0.606507	val-rmse:0.620214
# [950]	train-rmse:0.605697	val-rmse:0.619742
# [1000]	train-rmse:0.604907	val-rmse:0.619289
# [1050]	train-rmse:0.604218	val-rmse:0.618922
# [1100]	train-rmse:0.603649	val-rmse:0.618598
# [1150]	train-rmse:0.603111	val-rmse:0.618317
# [1200]	train-rmse:0.602579	val-rmse:0.618023
# [1250]	train-rmse:0.60212	val-rmse:0.617793
# [1300]	train-rmse:0.601698	val-rmse:0.617578
# [1350]	train-rmse:0.601252	val-rmse:0.617312
# [1400]	train-rmse:0.600809	val-rmse:0.61714
# [1450]	train-rmse:0.600405	val-rmse:0.616956
# [1500]	train-rmse:0.600024	val-rmse:0.616717
# [1550]	train-rmse:0.59966	val-rmse:0.616575
# [1600]	train-rmse:0.599321	val-rmse:0.616438
# [1650]	train-rmse:0.598977	val-rmse:0.616304
# [1700]	train-rmse:0.598662	val-rmse:0.616151
# [1750]	train-rmse:0.598314	val-rmse:0.615991
# [1800]	train-rmse:0.597975	val-rmse:0.615842
# [1850]	train-rmse:0.597658	val-rmse:0.615701
# [1900]	train-rmse:0.597369	val-rmse:0.615565
# [1950]	train-rmse:0.597035	val-rmse:0.615418
# [1999]	train-rmse:0.596771	val-rmse:0.615351
# ==================================================
# Step 14
# ==================================================
# [0]	train-rmse:1.14299	val-rmse:1.1394
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.945983	val-rmse:0.945606
# [100]	train-rmse:0.818683	val-rmse:0.820269
# [150]	train-rmse:0.738549	val-rmse:0.741353
# [200]	train-rmse:0.689404	val-rmse:0.692693
# [250]	train-rmse:0.659526	val-rmse:0.663099
# [300]	train-rmse:0.640787	val-rmse:0.644845
# [350]	train-rmse:0.628916	val-rmse:0.633289
# [400]	train-rmse:0.620977	val-rmse:0.625732
# [450]	train-rmse:0.615646	val-rmse:0.621003
# [500]	train-rmse:0.611477	val-rmse:0.617462
# [550]	train-rmse:0.608525	val-rmse:0.615072
# [600]	train-rmse:0.606197	val-rmse:0.613386
# [650]	train-rmse:0.604277	val-rmse:0.61208
# [700]	train-rmse:0.602562	val-rmse:0.610977
# [750]	train-rmse:0.601061	val-rmse:0.610168
# [800]	train-rmse:0.59988	val-rmse:0.609467
# [850]	train-rmse:0.598799	val-rmse:0.608892
# [900]	train-rmse:0.597848	val-rmse:0.608379
# [950]	train-rmse:0.597151	val-rmse:0.608048
# [1000]	train-rmse:0.596429	val-rmse:0.607734
# [1050]	train-rmse:0.595747	val-rmse:0.607428
# [1100]	train-rmse:0.595208	val-rmse:0.607159
# [1150]	train-rmse:0.594617	val-rmse:0.606842
# [1200]	train-rmse:0.594064	val-rmse:0.606578
# [1250]	train-rmse:0.593533	val-rmse:0.606366
# [1300]	train-rmse:0.593036	val-rmse:0.606178
# [1350]	train-rmse:0.592569	val-rmse:0.605968
# [1400]	train-rmse:0.592133	val-rmse:0.605754
# [1450]	train-rmse:0.591677	val-rmse:0.605562
# [1500]	train-rmse:0.591276	val-rmse:0.605346
# [1550]	train-rmse:0.590894	val-rmse:0.605164
# [1600]	train-rmse:0.59054	val-rmse:0.605016
# [1650]	train-rmse:0.590171	val-rmse:0.604824
# [1700]	train-rmse:0.589829	val-rmse:0.604682
# [1750]	train-rmse:0.589458	val-rmse:0.60451
# [1800]	train-rmse:0.589141	val-rmse:0.604351
# [1850]	train-rmse:0.588828	val-rmse:0.604222
# [1900]	train-rmse:0.58852	val-rmse:0.604104
# [1950]	train-rmse:0.58823	val-rmse:0.603963
# [1999]	train-rmse:0.587925	val-rmse:0.603811
# ==================================================
# Step 15
# ==================================================
# [0]	train-rmse:1.15847	val-rmse:1.14647
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.955918	val-rmse:0.947744
# [100]	train-rmse:0.824128	val-rmse:0.818639
# [150]	train-rmse:0.740326	val-rmse:0.736859
# [200]	train-rmse:0.688881	val-rmse:0.686775
# [250]	train-rmse:0.657395	val-rmse:0.656446
# [300]	train-rmse:0.637898	val-rmse:0.637767
# [350]	train-rmse:0.625384	val-rmse:0.625979
# [400]	train-rmse:0.617257	val-rmse:0.618451
# [450]	train-rmse:0.611593	val-rmse:0.613432
# [500]	train-rmse:0.607057	val-rmse:0.609381
# [550]	train-rmse:0.603732	val-rmse:0.606444
# [600]	train-rmse:0.601082	val-rmse:0.604227
# [650]	train-rmse:0.598838	val-rmse:0.602431
# [700]	train-rmse:0.596947	val-rmse:0.601046
# [750]	train-rmse:0.595256	val-rmse:0.599837
# [800]	train-rmse:0.593969	val-rmse:0.59903
# [850]	train-rmse:0.592835	val-rmse:0.598356
# [900]	train-rmse:0.591766	val-rmse:0.597734
# [950]	train-rmse:0.590834	val-rmse:0.597242
# [1000]	train-rmse:0.589954	val-rmse:0.596802
# [1050]	train-rmse:0.589169	val-rmse:0.596359
# [1100]	train-rmse:0.588378	val-rmse:0.595954
# [1150]	train-rmse:0.587673	val-rmse:0.595617
# [1200]	train-rmse:0.587031	val-rmse:0.595284
# [1250]	train-rmse:0.586422	val-rmse:0.594949
# [1300]	train-rmse:0.585786	val-rmse:0.594642
# [1350]	train-rmse:0.585218	val-rmse:0.594354
# [1400]	train-rmse:0.584647	val-rmse:0.594062
# [1450]	train-rmse:0.584124	val-rmse:0.593769
# [1500]	train-rmse:0.583659	val-rmse:0.593509
# [1550]	train-rmse:0.583207	val-rmse:0.593321
# [1600]	train-rmse:0.582769	val-rmse:0.59314
# [1650]	train-rmse:0.582272	val-rmse:0.592882
# [1700]	train-rmse:0.581823	val-rmse:0.592607
# [1750]	train-rmse:0.581458	val-rmse:0.592423
# [1800]	train-rmse:0.581058	val-rmse:0.592272
# [1850]	train-rmse:0.580675	val-rmse:0.592092
# [1900]	train-rmse:0.580355	val-rmse:0.59195
# [1950]	train-rmse:0.580009	val-rmse:0.591809
# [1999]	train-rmse:0.579625	val-rmse:0.591606
# ==================================================
# Step 16
# ==================================================
# [0]	train-rmse:1.09211	val-rmse:1.08758
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.911785	val-rmse:0.911636
# [100]	train-rmse:0.795454	val-rmse:0.798904
# [150]	train-rmse:0.722756	val-rmse:0.728828
# [200]	train-rmse:0.678462	val-rmse:0.686124
# [250]	train-rmse:0.651726	val-rmse:0.660554
# [300]	train-rmse:0.635612	val-rmse:0.645125
# [350]	train-rmse:0.625708	val-rmse:0.635724
# [400]	train-rmse:0.619409	val-rmse:0.629916
# [450]	train-rmse:0.615016	val-rmse:0.626054
# [500]	train-rmse:0.611792	val-rmse:0.623445
# [550]	train-rmse:0.608933	val-rmse:0.62156
# [600]	train-rmse:0.606753	val-rmse:0.620051
# [650]	train-rmse:0.604977	val-rmse:0.618927
# [700]	train-rmse:0.603407	val-rmse:0.617938
# [750]	train-rmse:0.602118	val-rmse:0.617202
# [800]	train-rmse:0.600981	val-rmse:0.616503
# [850]	train-rmse:0.599999	val-rmse:0.616001
# [900]	train-rmse:0.599108	val-rmse:0.615424
# [950]	train-rmse:0.598348	val-rmse:0.615014
# [1000]	train-rmse:0.597569	val-rmse:0.614572
# [1050]	train-rmse:0.596862	val-rmse:0.614175
# [1100]	train-rmse:0.596209	val-rmse:0.613799
# [1150]	train-rmse:0.595651	val-rmse:0.613487
# [1200]	train-rmse:0.595104	val-rmse:0.613187
# [1250]	train-rmse:0.59459	val-rmse:0.612892
# [1300]	train-rmse:0.594124	val-rmse:0.612657
# [1350]	train-rmse:0.593686	val-rmse:0.612387
# [1400]	train-rmse:0.593275	val-rmse:0.612173
# [1450]	train-rmse:0.592879	val-rmse:0.61196
# [1500]	train-rmse:0.592523	val-rmse:0.611763
# [1550]	train-rmse:0.592137	val-rmse:0.611563
# [1600]	train-rmse:0.591763	val-rmse:0.611381
# [1650]	train-rmse:0.591432	val-rmse:0.61121
# [1700]	train-rmse:0.591051	val-rmse:0.610991
# [1750]	train-rmse:0.590741	val-rmse:0.610827
# [1800]	train-rmse:0.590408	val-rmse:0.610656
# [1850]	train-rmse:0.59009	val-rmse:0.6105
# [1900]	train-rmse:0.589796	val-rmse:0.610374
# [1950]	train-rmse:0.589506	val-rmse:0.61022
# [1999]	train-rmse:0.589222	val-rmse:0.610106
# ==================================================
#
# Training Model No. 5 ...
# Parameters -->  {'colsample_bytree': 0.43624257381312836, 'gamma': 0.3130091445732128, 'eta': 0.005820013372709849, 'max_depth': 10, 'min_child_weight': 3, 'subsample': 0.7439761626945284}
# ==================================================
# Step 1
# ==================================================
# [0]	train-rmse:1.18386	val-rmse:1.14179
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.958108	val-rmse:0.926303
# [100]	train-rmse:0.801757	val-rmse:0.779947
# [150]	train-rmse:0.697198	val-rmse:0.685282
# [200]	train-rmse:0.628691	val-rmse:0.626039
# [250]	train-rmse:0.584053	val-rmse:0.5895
# [300]	train-rmse:0.555346	val-rmse:0.567706
# [350]	train-rmse:0.536891	val-rmse:0.555115
# [400]	train-rmse:0.52461	val-rmse:0.547991
# [450]	train-rmse:0.515962	val-rmse:0.543719
# [500]	train-rmse:0.509547	val-rmse:0.541029
# [550]	train-rmse:0.504444	val-rmse:0.539012
# [600]	train-rmse:0.50032	val-rmse:0.537832
# [650]	train-rmse:0.496722	val-rmse:0.537123
# [700]	train-rmse:0.49339	val-rmse:0.53647
# [750]	train-rmse:0.49033	val-rmse:0.535903
# [800]	train-rmse:0.487407	val-rmse:0.535495
# [850]	train-rmse:0.484642	val-rmse:0.535124
# [900]	train-rmse:0.482084	val-rmse:0.53477
# [950]	train-rmse:0.479575	val-rmse:0.534483
# [1000]	train-rmse:0.477206	val-rmse:0.534239
# [1050]	train-rmse:0.474814	val-rmse:0.534011
# [1100]	train-rmse:0.472467	val-rmse:0.533834
# [1150]	train-rmse:0.470252	val-rmse:0.533685
# [1200]	train-rmse:0.468115	val-rmse:0.533562
# [1250]	train-rmse:0.466099	val-rmse:0.533443
# [1300]	train-rmse:0.464058	val-rmse:0.533306
# [1350]	train-rmse:0.46205	val-rmse:0.533248
# [1400]	train-rmse:0.460103	val-rmse:0.533149
# [1450]	train-rmse:0.458104	val-rmse:0.533077
# [1500]	train-rmse:0.456125	val-rmse:0.533025
# [1550]	train-rmse:0.454127	val-rmse:0.532982
# [1600]	train-rmse:0.452208	val-rmse:0.532936
# [1650]	train-rmse:0.45019	val-rmse:0.532912
# [1700]	train-rmse:0.448235	val-rmse:0.532899
# [1750]	train-rmse:0.44622	val-rmse:0.532851
# [1800]	train-rmse:0.444338	val-rmse:0.532825
# [1850]	train-rmse:0.44241	val-rmse:0.532806
# [1900]	train-rmse:0.440499	val-rmse:0.532803
# [1950]	train-rmse:0.438559	val-rmse:0.532787
# [1999]	train-rmse:0.436688	val-rmse:0.532773
# ==================================================
# Step 2
# ==================================================
# [0]	train-rmse:1.10052	val-rmse:1.07552
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.902772	val-rmse:0.889907
# [100]	train-rmse:0.768057	val-rmse:0.766194
# [150]	train-rmse:0.679422	val-rmse:0.686995
# [200]	train-rmse:0.621921	val-rmse:0.637647
# [250]	train-rmse:0.58531	val-rmse:0.607797
# [300]	train-rmse:0.562033	val-rmse:0.590112
# [350]	train-rmse:0.546973	val-rmse:0.579675
# [400]	train-rmse:0.536843	val-rmse:0.573628
# [450]	train-rmse:0.52963	val-rmse:0.569979
# [500]	train-rmse:0.524177	val-rmse:0.567758
# [550]	train-rmse:0.519885	val-rmse:0.566241
# [600]	train-rmse:0.516099	val-rmse:0.565369
# [650]	train-rmse:0.512769	val-rmse:0.564757
# [700]	train-rmse:0.509637	val-rmse:0.564357
# [750]	train-rmse:0.50674	val-rmse:0.564023
# [800]	train-rmse:0.50397	val-rmse:0.563779
# [850]	train-rmse:0.501324	val-rmse:0.563558
# [900]	train-rmse:0.498657	val-rmse:0.563354
# [950]	train-rmse:0.496179	val-rmse:0.563128
# [1000]	train-rmse:0.493851	val-rmse:0.562959
# [1050]	train-rmse:0.491348	val-rmse:0.562849
# [1100]	train-rmse:0.488968	val-rmse:0.562751
# [1150]	train-rmse:0.486504	val-rmse:0.56269
# [1200]	train-rmse:0.484218	val-rmse:0.562611
# [1250]	train-rmse:0.481946	val-rmse:0.562582
# [1300]	train-rmse:0.479653	val-rmse:0.56251
# [1350]	train-rmse:0.477542	val-rmse:0.562472
# [1400]	train-rmse:0.475238	val-rmse:0.562415
# [1450]	train-rmse:0.473152	val-rmse:0.562365
# [1500]	train-rmse:0.470973	val-rmse:0.562318
# [1550]	train-rmse:0.468814	val-rmse:0.562323
# [1600]	train-rmse:0.466742	val-rmse:0.562291
# [1650]	train-rmse:0.464729	val-rmse:0.562251
# [1700]	train-rmse:0.462704	val-rmse:0.562206
# [1750]	train-rmse:0.460794	val-rmse:0.562178
# [1800]	train-rmse:0.458821	val-rmse:0.56218
# [1850]	train-rmse:0.456756	val-rmse:0.562179
# [1900]	train-rmse:0.454769	val-rmse:0.562179
# [1950]	train-rmse:0.452857	val-rmse:0.562165
# [1999]	train-rmse:0.451002	val-rmse:0.562143
# ==================================================
# Step 3
# ==================================================
# [0]	train-rmse:1.18938	val-rmse:1.18891
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.96491	val-rmse:0.976995
# [100]	train-rmse:0.810028	val-rmse:0.832711
# [150]	train-rmse:0.706242	val-rmse:0.737953
# [200]	train-rmse:0.638647	val-rmse:0.677722
# [250]	train-rmse:0.595276	val-rmse:0.640084
# [300]	train-rmse:0.567587	val-rmse:0.616991
# [350]	train-rmse:0.549631	val-rmse:0.602863
# [400]	train-rmse:0.537662	val-rmse:0.594194
# [450]	train-rmse:0.529205	val-rmse:0.588702
# [500]	train-rmse:0.52302	val-rmse:0.585132
# [550]	train-rmse:0.518044	val-rmse:0.582849
# [600]	train-rmse:0.513864	val-rmse:0.581286
# [650]	train-rmse:0.510241	val-rmse:0.5802
# [700]	train-rmse:0.506888	val-rmse:0.579378
# [750]	train-rmse:0.503946	val-rmse:0.578758
# [800]	train-rmse:0.501027	val-rmse:0.578316
# [850]	train-rmse:0.498146	val-rmse:0.57798
# [900]	train-rmse:0.495503	val-rmse:0.577704
# [950]	train-rmse:0.492884	val-rmse:0.577522
# [1000]	train-rmse:0.490416	val-rmse:0.577363
# [1050]	train-rmse:0.488011	val-rmse:0.577253
# [1100]	train-rmse:0.485599	val-rmse:0.577112
# [1150]	train-rmse:0.483263	val-rmse:0.577037
# [1200]	train-rmse:0.480991	val-rmse:0.576952
# [1250]	train-rmse:0.478689	val-rmse:0.576911
# [1300]	train-rmse:0.476458	val-rmse:0.576879
# [1350]	train-rmse:0.474409	val-rmse:0.57687
# [1400]	train-rmse:0.472294	val-rmse:0.57682
# [1450]	train-rmse:0.470349	val-rmse:0.576773
# [1500]	train-rmse:0.468282	val-rmse:0.57674
# [1550]	train-rmse:0.466361	val-rmse:0.576722
# [1600]	train-rmse:0.464333	val-rmse:0.57671
# [1650]	train-rmse:0.462314	val-rmse:0.576681
# [1700]	train-rmse:0.460402	val-rmse:0.576678
# [1750]	train-rmse:0.458536	val-rmse:0.576664
# [1800]	train-rmse:0.456677	val-rmse:0.576653
# [1850]	train-rmse:0.454769	val-rmse:0.576637
# [1900]	train-rmse:0.452889	val-rmse:0.576624
# [1950]	train-rmse:0.45101	val-rmse:0.576632
# [1999]	train-rmse:0.449283	val-rmse:0.576636
# ==================================================
# Step 4
# ==================================================
# [0]	train-rmse:1.36766	val-rmse:1.30506
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:1.09389	val-rmse:1.0489
# [100]	train-rmse:0.902898	val-rmse:0.874778
# [150]	train-rmse:0.773351	val-rmse:0.761384
# [200]	train-rmse:0.687842	val-rmse:0.690657
# [250]	train-rmse:0.632496	val-rmse:0.648172
# [300]	train-rmse:0.597203	val-rmse:0.623381
# [350]	train-rmse:0.574433	val-rmse:0.609204
# [400]	train-rmse:0.559357	val-rmse:0.601248
# [450]	train-rmse:0.549018	val-rmse:0.596745
# [500]	train-rmse:0.541498	val-rmse:0.593965
# [550]	train-rmse:0.53563	val-rmse:0.592451
# [600]	train-rmse:0.530775	val-rmse:0.591471
# [650]	train-rmse:0.526523	val-rmse:0.590878
# [700]	train-rmse:0.522734	val-rmse:0.590445
# [750]	train-rmse:0.519262	val-rmse:0.590105
# [800]	train-rmse:0.516042	val-rmse:0.589777
# [850]	train-rmse:0.512975	val-rmse:0.589554
# [900]	train-rmse:0.51012	val-rmse:0.589266
# [950]	train-rmse:0.507269	val-rmse:0.589044
# [1000]	train-rmse:0.504793	val-rmse:0.588764
# [1050]	train-rmse:0.502149	val-rmse:0.588549
# [1100]	train-rmse:0.499635	val-rmse:0.588371
# [1150]	train-rmse:0.497153	val-rmse:0.588211
# [1200]	train-rmse:0.494762	val-rmse:0.588074
# [1250]	train-rmse:0.49232	val-rmse:0.587979
# [1300]	train-rmse:0.490061	val-rmse:0.587915
# [1350]	train-rmse:0.487706	val-rmse:0.587814
# [1400]	train-rmse:0.485358	val-rmse:0.587783
# [1450]	train-rmse:0.483301	val-rmse:0.587717
# [1500]	train-rmse:0.481261	val-rmse:0.587667
# [1550]	train-rmse:0.479151	val-rmse:0.587606
# [1600]	train-rmse:0.47704	val-rmse:0.587568
# [1650]	train-rmse:0.474922	val-rmse:0.587553
# [1700]	train-rmse:0.472981	val-rmse:0.58751
# [1750]	train-rmse:0.470995	val-rmse:0.587494
# [1800]	train-rmse:0.469045	val-rmse:0.587491
# [1850]	train-rmse:0.467059	val-rmse:0.587503
# Stopping. Best iteration:
# [1737]	train-rmse:0.471505	val-rmse:0.587482
#
# ==================================================
# Step 5
# ==================================================
# [0]	train-rmse:1.41128	val-rmse:1.34676
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:1.127	val-rmse:1.07773
# [100]	train-rmse:0.927869	val-rmse:0.894065
# [150]	train-rmse:0.792321	val-rmse:0.773941
# [200]	train-rmse:0.702325	val-rmse:0.698684
# [250]	train-rmse:0.643747	val-rmse:0.653231
# [300]	train-rmse:0.605909	val-rmse:0.62647
# [350]	train-rmse:0.581342	val-rmse:0.611212
# [400]	train-rmse:0.565032	val-rmse:0.602722
# [450]	train-rmse:0.553668	val-rmse:0.597885
# [500]	train-rmse:0.545223	val-rmse:0.594898
# [550]	train-rmse:0.538691	val-rmse:0.593259
# [600]	train-rmse:0.53325	val-rmse:0.592179
# [650]	train-rmse:0.528599	val-rmse:0.591505
# [700]	train-rmse:0.524423	val-rmse:0.590985
# [750]	train-rmse:0.520743	val-rmse:0.590531
# [800]	train-rmse:0.517382	val-rmse:0.590065
# [850]	train-rmse:0.51416	val-rmse:0.589665
# [900]	train-rmse:0.511223	val-rmse:0.589283
# [950]	train-rmse:0.508306	val-rmse:0.589009
# [1000]	train-rmse:0.505726	val-rmse:0.588722
# [1050]	train-rmse:0.502897	val-rmse:0.588497
# [1100]	train-rmse:0.500119	val-rmse:0.588322
# [1150]	train-rmse:0.4975	val-rmse:0.588202
# [1200]	train-rmse:0.495055	val-rmse:0.588108
# [1250]	train-rmse:0.492487	val-rmse:0.588045
# [1300]	train-rmse:0.490087	val-rmse:0.587957
# [1350]	train-rmse:0.487753	val-rmse:0.587877
# [1400]	train-rmse:0.485435	val-rmse:0.5878
# [1450]	train-rmse:0.483089	val-rmse:0.587751
# [1500]	train-rmse:0.480847	val-rmse:0.587735
# [1550]	train-rmse:0.47867	val-rmse:0.587675
# [1600]	train-rmse:0.476407	val-rmse:0.587661
# [1650]	train-rmse:0.474313	val-rmse:0.587611
# [1700]	train-rmse:0.472073	val-rmse:0.587584
# [1750]	train-rmse:0.469963	val-rmse:0.587524
# [1800]	train-rmse:0.468046	val-rmse:0.587517
# [1850]	train-rmse:0.465938	val-rmse:0.587504
# [1900]	train-rmse:0.463871	val-rmse:0.587481
# [1950]	train-rmse:0.461763	val-rmse:0.587474
# [1999]	train-rmse:0.459831	val-rmse:0.587467
# ==================================================
# Step 6
# ==================================================
# [0]	train-rmse:1.23123	val-rmse:1.23222
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:1.00129	val-rmse:1.01281
# [100]	train-rmse:0.843323	val-rmse:0.863921
# [150]	train-rmse:0.737964	val-rmse:0.765345
# [200]	train-rmse:0.669555	val-rmse:0.702522
# [250]	train-rmse:0.62578	val-rmse:0.663055
# [300]	train-rmse:0.597715	val-rmse:0.638403
# [350]	train-rmse:0.579449	val-rmse:0.622988
# [400]	train-rmse:0.567139	val-rmse:0.613428
# ...
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.650796	val-rmse:0.68659
# [100]	train-rmse:0.604295	val-rmse:0.632081
# [150]	train-rmse:0.593695	val-rmse:0.621912
# [200]	train-rmse:0.589272	val-rmse:0.619115
# [250]	train-rmse:0.586443	val-rmse:0.617577
# [300]	train-rmse:0.58436	val-rmse:0.616746
# [350]	train-rmse:0.58263	val-rmse:0.616142
# [400]	train-rmse:0.581172	val-rmse:0.615406
# [450]	train-rmse:0.580043	val-rmse:0.614786
# [500]	train-rmse:0.579002	val-rmse:0.614436
# [550]	train-rmse:0.578014	val-rmse:0.613819
# [600]	train-rmse:0.577106	val-rmse:0.613327
# [650]	train-rmse:0.576326	val-rmse:0.613066
# [700]	train-rmse:0.575566	val-rmse:0.612856
# [750]	train-rmse:0.574816	val-rmse:0.612531
# [800]	train-rmse:0.5742	val-rmse:0.612254
# [850]	train-rmse:0.573547	val-rmse:0.612111
# [900]	train-rmse:0.572944	val-rmse:0.611949
# [950]	train-rmse:0.572333	val-rmse:0.611734
# [1000]	train-rmse:0.571738	val-rmse:0.611523
# [1050]	train-rmse:0.571146	val-rmse:0.611259
# [1100]	train-rmse:0.57061	val-rmse:0.611141
# [1150]	train-rmse:0.570146	val-rmse:0.611032
# [1200]	train-rmse:0.569666	val-rmse:0.610956
# [1250]	train-rmse:0.569233	val-rmse:0.610721
# [1300]	train-rmse:0.568803	val-rmse:0.610639
# [1350]	train-rmse:0.568362	val-rmse:0.610527
# [1400]	train-rmse:0.567938	val-rmse:0.610457
# [1450]	train-rmse:0.56747	val-rmse:0.610318
# [1500]	train-rmse:0.567068	val-rmse:0.610202
# [1550]	train-rmse:0.566667	val-rmse:0.610073
# [1600]	train-rmse:0.56629	val-rmse:0.609977
# [1650]	train-rmse:0.565923	val-rmse:0.609903
# [1700]	train-rmse:0.565562	val-rmse:0.609862
# [1750]	train-rmse:0.565203	val-rmse:0.609826
# [1800]	train-rmse:0.564859	val-rmse:0.609802
# [1850]	train-rmse:0.56451	val-rmse:0.609772
# [1900]	train-rmse:0.564165	val-rmse:0.609598
# [1950]	train-rmse:0.563852	val-rmse:0.609621
# [1999]	train-rmse:0.563536	val-rmse:0.609622
# ==================================================
# Step 10
# ==================================================
# [0]	train-rmse:1.15689	val-rmse:1.18419
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.668611	val-rmse:0.693636
# [100]	train-rmse:0.611779	val-rmse:0.632271
# [150]	train-rmse:0.598896	val-rmse:0.619931
# [200]	train-rmse:0.592894	val-rmse:0.615546
# [250]	train-rmse:0.589485	val-rmse:0.613594
# [300]	train-rmse:0.586711	val-rmse:0.611996
# [350]	train-rmse:0.584559	val-rmse:0.610665
# [400]	train-rmse:0.582725	val-rmse:0.609728
# [450]	train-rmse:0.581195	val-rmse:0.60901
# [500]	train-rmse:0.579858	val-rmse:0.608318
# [550]	train-rmse:0.578608	val-rmse:0.607795
# [600]	train-rmse:0.577437	val-rmse:0.607234
# [650]	train-rmse:0.576421	val-rmse:0.606821
# [700]	train-rmse:0.575441	val-rmse:0.60642
# [750]	train-rmse:0.574605	val-rmse:0.606171
# [800]	train-rmse:0.573806	val-rmse:0.605858
# [850]	train-rmse:0.572988	val-rmse:0.605635
# [900]	train-rmse:0.572275	val-rmse:0.60539
# [950]	train-rmse:0.571587	val-rmse:0.605111
# [1000]	train-rmse:0.570978	val-rmse:0.605043
# [1050]	train-rmse:0.570362	val-rmse:0.604871
# [1100]	train-rmse:0.56979	val-rmse:0.60491
# [1150]	train-rmse:0.569212	val-rmse:0.604669
# [1200]	train-rmse:0.568634	val-rmse:0.604563
# [1250]	train-rmse:0.568084	val-rmse:0.604436
# [1300]	train-rmse:0.567533	val-rmse:0.604263
# [1350]	train-rmse:0.567066	val-rmse:0.60419
# [1400]	train-rmse:0.56658	val-rmse:0.604094
# [1450]	train-rmse:0.566106	val-rmse:0.603963
# [1500]	train-rmse:0.565641	val-rmse:0.603869
# [1550]	train-rmse:0.56516	val-rmse:0.603601
# [1600]	train-rmse:0.564695	val-rmse:0.603477
# [1650]	train-rmse:0.564186	val-rmse:0.603265
# [1700]	train-rmse:0.563766	val-rmse:0.603076
# [1750]	train-rmse:0.563362	val-rmse:0.602998
# [1800]	train-rmse:0.562965	val-rmse:0.602941
# [1850]	train-rmse:0.562609	val-rmse:0.602907
# [1900]	train-rmse:0.562245	val-rmse:0.602922
# [1950]	train-rmse:0.561894	val-rmse:0.602964
# [1999]	train-rmse:0.56152	val-rmse:0.60285
# ==================================================
# Step 11
# ==================================================
# [0]	train-rmse:1.27633	val-rmse:1.27116
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.690469	val-rmse:0.695743
# [100]	train-rmse:0.626125	val-rmse:0.633787
# [150]	train-rmse:0.61283	val-rmse:0.623252
# [200]	train-rmse:0.607241	val-rmse:0.619946
# [250]	train-rmse:0.603539	val-rmse:0.618109
# [300]	train-rmse:0.601033	val-rmse:0.616679
# [350]	train-rmse:0.598852	val-rmse:0.61546
# [400]	train-rmse:0.597067	val-rmse:0.614388
# [450]	train-rmse:0.595467	val-rmse:0.613795
# [500]	train-rmse:0.594105	val-rmse:0.613207
# [550]	train-rmse:0.592908	val-rmse:0.612546
# [600]	train-rmse:0.591775	val-rmse:0.612109
# [650]	train-rmse:0.590756	val-rmse:0.61176
# [700]	train-rmse:0.589766	val-rmse:0.611508
# [750]	train-rmse:0.588787	val-rmse:0.611162
# [800]	train-rmse:0.587917	val-rmse:0.610847
# [850]	train-rmse:0.587131	val-rmse:0.610587
# [900]	train-rmse:0.586381	val-rmse:0.610386
# [950]	train-rmse:0.585608	val-rmse:0.610228
# [1000]	train-rmse:0.584935	val-rmse:0.609966
# [1050]	train-rmse:0.584211	val-rmse:0.609828
# [1100]	train-rmse:0.583565	val-rmse:0.609635
# [1150]	train-rmse:0.582935	val-rmse:0.609256
# [1200]	train-rmse:0.582346	val-rmse:0.6091
# [1250]	train-rmse:0.581729	val-rmse:0.608938
# [1300]	train-rmse:0.581153	val-rmse:0.608791
# [1350]	train-rmse:0.580636	val-rmse:0.608679
# [1400]	train-rmse:0.580107	val-rmse:0.608505
# [1450]	train-rmse:0.579624	val-rmse:0.608447
# [1500]	train-rmse:0.579122	val-rmse:0.608343
# [1550]	train-rmse:0.578635	val-rmse:0.608293
# [1600]	train-rmse:0.578169	val-rmse:0.608203
# [1650]	train-rmse:0.577731	val-rmse:0.608096
# [1700]	train-rmse:0.577318	val-rmse:0.608089
# [1750]	train-rmse:0.576885	val-rmse:0.608028
# [1800]	train-rmse:0.57643	val-rmse:0.608071
# [1850]	train-rmse:0.576024	val-rmse:0.608016
# [1900]	train-rmse:0.575592	val-rmse:0.608002
# [1950]	train-rmse:0.57517	val-rmse:0.607929
# [1999]	train-rmse:0.574792	val-rmse:0.607819
# ==================================================
# Step 12
# ==================================================
# [0]	train-rmse:1.33364	val-rmse:1.31346
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.709402	val-rmse:0.706842
# [100]	train-rmse:0.638662	val-rmse:0.643496
# [150]	train-rmse:0.623376	val-rmse:0.632989
# [200]	train-rmse:0.616872	val-rmse:0.62889
# [250]	train-rmse:0.6123	val-rmse:0.626649
# [300]	train-rmse:0.609381	val-rmse:0.625215
# [350]	train-rmse:0.606877	val-rmse:0.623828
# [400]	train-rmse:0.604741	val-rmse:0.622912
# [450]	train-rmse:0.603075	val-rmse:0.622045
# [500]	train-rmse:0.601526	val-rmse:0.621215
# [550]	train-rmse:0.60016	val-rmse:0.620671
# [600]	train-rmse:0.59894	val-rmse:0.620092
# [650]	train-rmse:0.597693	val-rmse:0.619628
# [700]	train-rmse:0.596786	val-rmse:0.619298
# [750]	train-rmse:0.595751	val-rmse:0.618849
# [800]	train-rmse:0.594739	val-rmse:0.618491
# [850]	train-rmse:0.5939	val-rmse:0.618285
# [900]	train-rmse:0.593029	val-rmse:0.618135
# [950]	train-rmse:0.592243	val-rmse:0.617931
# [1000]	train-rmse:0.591449	val-rmse:0.617826
# [1050]	train-rmse:0.590723	val-rmse:0.617541
# [1100]	train-rmse:0.590065	val-rmse:0.617519
# [1150]	train-rmse:0.589393	val-rmse:0.617191
# [1200]	train-rmse:0.588755	val-rmse:0.616968
# [1250]	train-rmse:0.588112	val-rmse:0.616847
# [1300]	train-rmse:0.587437	val-rmse:0.616611
# [1350]	train-rmse:0.586881	val-rmse:0.616408
# [1400]	train-rmse:0.586274	val-rmse:0.616288
# [1450]	train-rmse:0.585758	val-rmse:0.616162
# [1500]	train-rmse:0.585228	val-rmse:0.616055
# [1550]	train-rmse:0.584722	val-rmse:0.615964
# [1600]	train-rmse:0.584225	val-rmse:0.615893
# [1650]	train-rmse:0.583717	val-rmse:0.615815
# [1700]	train-rmse:0.583209	val-rmse:0.615685
# [1750]	train-rmse:0.582712	val-rmse:0.61565
# [1800]	train-rmse:0.582241	val-rmse:0.615567
# [1850]	train-rmse:0.581745	val-rmse:0.615481
# [1900]	train-rmse:0.581326	val-rmse:0.615377
# [1950]	train-rmse:0.580875	val-rmse:0.61537
# [1999]	train-rmse:0.580445	val-rmse:0.615197
# ==================================================
# Step 13
# ==================================================
# [0]	train-rmse:1.17371	val-rmse:1.17013
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.677305	val-rmse:0.683196
# [100]	train-rmse:0.623528	val-rmse:0.63147
# [150]	train-rmse:0.611596	val-rmse:0.622889
# [200]	train-rmse:0.60649	val-rmse:0.620061
# [250]	train-rmse:0.603468	val-rmse:0.618476
# [300]	train-rmse:0.601379	val-rmse:0.617409
# [350]	train-rmse:0.599558	val-rmse:0.616451
# [400]	train-rmse:0.598041	val-rmse:0.615832
# [450]	train-rmse:0.596716	val-rmse:0.615387
# [500]	train-rmse:0.595552	val-rmse:0.614771
# [550]	train-rmse:0.594441	val-rmse:0.614493
# [600]	train-rmse:0.593375	val-rmse:0.614115
# [650]	train-rmse:0.592485	val-rmse:0.613798
# [700]	train-rmse:0.59165	val-rmse:0.613611
# [750]	train-rmse:0.590621	val-rmse:0.613247
# [800]	train-rmse:0.589904	val-rmse:0.612995
# [850]	train-rmse:0.589168	val-rmse:0.612776
# [900]	train-rmse:0.588458	val-rmse:0.612625
# [950]	train-rmse:0.587797	val-rmse:0.612449
# [1000]	train-rmse:0.58713	val-rmse:0.612364
# [1050]	train-rmse:0.586527	val-rmse:0.612191
# [1100]	train-rmse:0.585941	val-rmse:0.612145
# [1150]	train-rmse:0.585412	val-rmse:0.611996
# [1200]	train-rmse:0.584846	val-rmse:0.611927
# [1250]	train-rmse:0.584343	val-rmse:0.611939
# [1300]	train-rmse:0.583831	val-rmse:0.611811
# [1350]	train-rmse:0.583319	val-rmse:0.611797
# [1400]	train-rmse:0.582859	val-rmse:0.611758
# [1450]	train-rmse:0.582395	val-rmse:0.611689
# [1500]	train-rmse:0.581922	val-rmse:0.611602
# [1550]	train-rmse:0.581475	val-rmse:0.611558
# [1600]	train-rmse:0.581077	val-rmse:0.611591
# [1650]	train-rmse:0.580678	val-rmse:0.61153
# [1700]	train-rmse:0.580297	val-rmse:0.611538
# [1750]	train-rmse:0.579918	val-rmse:0.611488
# [1800]	train-rmse:0.579495	val-rmse:0.611394
# [1850]	train-rmse:0.5791	val-rmse:0.611336
# [1900]	train-rmse:0.578713	val-rmse:0.61124
# [1950]	train-rmse:0.578345	val-rmse:0.611276
# [1999]	train-rmse:0.577957	val-rmse:0.611257
# ==================================================
# Step 14
# ==================================================
# [0]	train-rmse:1.12585	val-rmse:1.12229
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.665938	val-rmse:0.669417
# [100]	train-rmse:0.614778	val-rmse:0.62019
# [150]	train-rmse:0.603048	val-rmse:0.6115
# [200]	train-rmse:0.598084	val-rmse:0.608692
# [250]	train-rmse:0.594974	val-rmse:0.607119
# [300]	train-rmse:0.592691	val-rmse:0.606297
# [350]	train-rmse:0.590781	val-rmse:0.605403
# [400]	train-rmse:0.589069	val-rmse:0.60464
# [450]	train-rmse:0.587594	val-rmse:0.604098
# [500]	train-rmse:0.586431	val-rmse:0.60367
# [550]	train-rmse:0.585271	val-rmse:0.60314
# [600]	train-rmse:0.584282	val-rmse:0.602868
# [650]	train-rmse:0.583369	val-rmse:0.602592
# [700]	train-rmse:0.582518	val-rmse:0.602343
# [750]	train-rmse:0.5817	val-rmse:0.602068
# [800]	train-rmse:0.580987	val-rmse:0.602015
# [850]	train-rmse:0.58028	val-rmse:0.602005
# [900]	train-rmse:0.579563	val-rmse:0.601774
# [950]	train-rmse:0.578919	val-rmse:0.601588
# [1000]	train-rmse:0.578338	val-rmse:0.601517
# [1050]	train-rmse:0.577774	val-rmse:0.601401
# [1100]	train-rmse:0.577191	val-rmse:0.601248
# [1150]	train-rmse:0.57664	val-rmse:0.601118
# [1200]	train-rmse:0.5761	val-rmse:0.601037
# [1250]	train-rmse:0.575597	val-rmse:0.600972
# [1300]	train-rmse:0.575065	val-rmse:0.60085
# [1350]	train-rmse:0.574559	val-rmse:0.600786
# [1400]	train-rmse:0.574056	val-rmse:0.600787
# [1450]	train-rmse:0.573602	val-rmse:0.600836
# Stopping. Best iteration:
# [1352]	train-rmse:0.574543	val-rmse:0.600782
#
# ==================================================
# Step 15
# ==================================================
# [0]	train-rmse:1.14077	val-rmse:1.12905
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.664556	val-rmse:0.663397
# [100]	train-rmse:0.609944	val-rmse:0.611869
# [150]	train-rmse:0.597221	val-rmse:0.601377
# [200]	train-rmse:0.591327	val-rmse:0.59761
# [250]	train-rmse:0.587806	val-rmse:0.595763
# [300]	train-rmse:0.584965	val-rmse:0.594315
# [350]	train-rmse:0.582672	val-rmse:0.593205
# [400]	train-rmse:0.580832	val-rmse:0.592309
# [450]	train-rmse:0.579303	val-rmse:0.591624
# [500]	train-rmse:0.577949	val-rmse:0.590975
# [550]	train-rmse:0.576564	val-rmse:0.590369
# [600]	train-rmse:0.575496	val-rmse:0.589901
# [650]	train-rmse:0.574394	val-rmse:0.589563
# [700]	train-rmse:0.573406	val-rmse:0.589278
# [750]	train-rmse:0.572467	val-rmse:0.588959
# [800]	train-rmse:0.571698	val-rmse:0.588817
# [850]	train-rmse:0.570911	val-rmse:0.588563
# [900]	train-rmse:0.570077	val-rmse:0.588378
# [950]	train-rmse:0.569277	val-rmse:0.588073
# [1000]	train-rmse:0.568696	val-rmse:0.58792
# [1050]	train-rmse:0.568098	val-rmse:0.587735
# [1100]	train-rmse:0.567531	val-rmse:0.58761
# [1150]	train-rmse:0.566942	val-rmse:0.587393
# [1200]	train-rmse:0.566419	val-rmse:0.587211
# [1250]	train-rmse:0.565903	val-rmse:0.587171
# [1300]	train-rmse:0.565336	val-rmse:0.587101
# [1350]	train-rmse:0.564824	val-rmse:0.587088
# [1400]	train-rmse:0.564399	val-rmse:0.586986
# [1450]	train-rmse:0.563884	val-rmse:0.586846
# [1500]	train-rmse:0.563453	val-rmse:0.586802
# [1550]	train-rmse:0.563001	val-rmse:0.586731
# [1600]	train-rmse:0.56255	val-rmse:0.586649
# [1650]	train-rmse:0.562092	val-rmse:0.586526
# [1700]	train-rmse:0.561626	val-rmse:0.586442
# [1750]	train-rmse:0.561222	val-rmse:0.586392
# [1800]	train-rmse:0.560806	val-rmse:0.58639
# [1850]	train-rmse:0.560432	val-rmse:0.586304
# [1900]	train-rmse:0.560082	val-rmse:0.586266
# [1950]	train-rmse:0.559716	val-rmse:0.586216
# [1999]	train-rmse:0.559354	val-rmse:0.586174
# ==================================================
# Step 16
# ==================================================
# [0]	train-rmse:1.07617	val-rmse:1.07188
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 125 rounds.
# [50]	train-rmse:0.657668	val-rmse:0.666155
# [100]	train-rmse:0.613734	val-rmse:0.624867
# [150]	train-rmse:0.603258	val-rmse:0.617922
# [200]	train-rmse:0.59877	val-rmse:0.615228
# [250]	train-rmse:0.59595	val-rmse:0.613865
# [300]	train-rmse:0.593727	val-rmse:0.612731
# [350]	train-rmse:0.5921	val-rmse:0.611913
# [400]	train-rmse:0.590545	val-rmse:0.611114
# [450]	train-rmse:0.589315	val-rmse:0.610382
# [500]	train-rmse:0.588055	val-rmse:0.609775
# [550]	train-rmse:0.586913	val-rmse:0.609211
# [600]	train-rmse:0.585917	val-rmse:0.608859
# [650]	train-rmse:0.585021	val-rmse:0.608544
# [700]	train-rmse:0.584132	val-rmse:0.608359
# [750]	train-rmse:0.58327	val-rmse:0.608241
# [800]	train-rmse:0.582497	val-rmse:0.608037
# [850]	train-rmse:0.581779	val-rmse:0.60786
# [900]	train-rmse:0.581094	val-rmse:0.607574
# [950]	train-rmse:0.580446	val-rmse:0.6074
# [1000]	train-rmse:0.579855	val-rmse:0.607357
# [1050]	train-rmse:0.579226	val-rmse:0.607211
# [1100]	train-rmse:0.578542	val-rmse:0.607106
# [1150]	train-rmse:0.577993	val-rmse:0.606933
# [1200]	train-rmse:0.577449	val-rmse:0.606804
# [1250]	train-rmse:0.576896	val-rmse:0.606612
# [1300]	train-rmse:0.576351	val-rmse:0.606548
# [1350]	train-rmse:0.575877	val-rmse:0.606436
# [1400]	train-rmse:0.5754	val-rmse:0.606397
# [1450]	train-rmse:0.57497	val-rmse:0.606326
# [1500]	train-rmse:0.574538	val-rmse:0.606203
# [1550]	train-rmse:0.574066	val-rmse:0.606187
# [1600]	train-rmse:0.573615	val-rmse:0.606112
# [1650]	train-rmse:0.573181	val-rmse:0.60601
# [1700]	train-rmse:0.572739	val-rmse:0.605974
# [1750]	train-rmse:0.572336	val-rmse:0.605893
# [1800]	train-rmse:0.571904	val-rmse:0.605866
# [1850]	train-rmse:0.571537	val-rmse:0.605837
# [1900]	train-rmse:0.571164	val-rmse:0.605798
# [1950]	train-rmse:0.570774	val-rmse:0.605742
# [1999]	train-rmse:0.570423	val-rmse:0.605694
# CPU times: user 3h 12min 52s, sys: 1h 38min 15s, total: 4h 51min 7s
# Wall time: 4h 51min 11s

# %%
print("""Best parameters:
- colsample_bytree=%.6f
- gamma=%.6f
- eta=%.6f
- max_depth=%d
- min_child_weight=%d
- subsample=%.6f """ % (results.x[0], results.x[1],
                            results.x[2], results.x[3],
                            results.x[4],results.x[5]))
# Out:
# Best parameters:
# - colsample_bytree=0.436243
# - gamma=0.313009
# - eta=0.005820
# - max_depth=10
# - min_child_weight=3
# - subsample=0.743976

# %%
"Best score = %.6f" % results.fun
# Out:
# 'Best score = 0.594137'

# %% [markdown]
# ### Observations :

# %% [markdown]
# * Model --> **Xgboost**
# * Best Parameters :
#     * *colsample_bytree* = **0.436243**
#     * *gamma* = **0.313009**
#     * *eta* = **0.005820**
#     * *max_depth* = **10**
#     * *min_child_weight* = **3**
#     * *subsample* = **0.743976**
# * Best Score (NWRMSLE) --> **0.5941**
